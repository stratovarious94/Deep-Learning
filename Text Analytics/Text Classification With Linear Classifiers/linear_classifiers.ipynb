# %%
#!pip install -U scikit-learn
#!pip install pandas

# %%
import os
import glob

'''
Function that recursively reads text files with
a specific extension under a given root directory
'''

def read_data(directory,file_extension,class_label):
    
    data = []
    index = []
    for filename in glob.glob(directory+'/**/*'+file_extension, recursive=True):
        email_content = ""
        with open(filename, 'r',encoding='utf-8', errors='ignore') as email:
            for line in email:
                line = line.strip('\n')
                line = line.strip('\t')
                email_content+= line
        email.close()
        data.append({'text': email_content, 'label': class_label})
        index.append(filename)
                    
    return data,index

# %%
import pandas as pd
from sklearn.utils import shuffle

'''
Read spam and ham emails, convert to pandas,
concatenate and random shuffle
--Enron dataset is downloaded from http://nlp.cs.aueb.gr/software_and_datasets/Enron-Spam/index.html (pre-processed form)
'''

Enron_dataset_dir = "C:\\Users\\Manolis\\Desktop\\lab2_TA\\Enron_dataset"
Ham_data,index_hamdata = read_data(Enron_dataset_dir,".ham.txt","Ham")
Spam_data,index_spamdata = read_data(Enron_dataset_dir,".spam.txt","Spam")
data = pd.DataFrame(Ham_data,index =index_hamdata)
data = data.append(pd.DataFrame(Spam_data,index =index_spamdata))
#shufle dataframe
data = shuffle(data,random_state = 456987)
pd.set_option("max_colwidth",2000)
data
# Out:
#                                                                                               label  \
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron4\spam\1306.2004-05-29.GP.spam.txt         Spam
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron4\spam\0347.2004-02-05.GP.spam.txt         Spam
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron6\spam\2646.2005-01-11.BG.spam.txt         Spam
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron2\ham\3439.2000-11-27.kaminski.ham.txt      Ham
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron3\ham\4567.2001-12-13.kitchen.ham.txt       Ham
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron6\ham\3534.2001-05-02.lokay.ham.txt         Ham
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron2\ham\0779.2000-03-19.kaminski.ham.txt      Ham
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron6\spam\2574.2005-01-07.BG.spam.txt         Spam
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron6\ham\0381.2000-07-14.lokay.ham.txt         Ham
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron5\spam\0498.2002-07-16.SA_and_HP.spam.txt  Spam
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron4\spam\5966.2005-09-03.GP.spam.txt         Spam
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron4\ham\5225.2002-01-23.williams.ham.txt      Ham
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron2\ham\1669.2000-06-30.kaminski.ham.txt      Ham
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron3\ham\4653.2001-12-20.kitchen.ham.txt       Ham
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron4\spam\5363.2005-06-06.GP.spam.txt         Spam
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron2\spam\4834.2005-07-16.SA_and_HP.spam.txt  Spam
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron3\ham\2520.2001-09-14.kitchen.ham.txt       Ham
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron3\ham\1977.2001-08-10.kitchen.ham.txt       Ham
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron4\spam\3952.2005-01-18.GP.spam.txt         Spam
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron5\spam\5162.2005-07-22.SA_and_HP.spam.txt  Spam
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron1\ham\3786.2001-03-14.farmer.ham.txt        Ham
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron1\ham\2862.2000-11-15.farmer.ham.txt        Ham
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron1\ham\4416.2001-04-27.farmer.ham.txt        Ham
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron3\ham\1219.2001-06-18.kitchen.ham.txt       Ham
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron4\ham\0149.2001-04-16.williams.ham.txt      Ham
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron2\spam\3033.2005-06-29.SA_and_HP.spam.txt  Spam
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron2\spam\2389.2005-06-24.SA_and_HP.spam.txt  Spam
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron2\ham\0451.2000-02-14.kaminski.ham.txt      Ham
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron3\ham\0720.2001-04-20.kitchen.ham.txt       Ham
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron4\ham\4731.2002-01-14.williams.ham.txt      Ham
# ...                                                                                             ...
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron6\spam\2943.2005-01-22.BG.spam.txt         Spam
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron2\ham\2161.2000-08-11.kaminski.ham.txt      Ham
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron5\spam\4445.2005-07-19.SA_and_HP.spam.txt  Spam
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron1\ham\1172.2000-05-30.farmer.ham.txt        Ham
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron3\ham\3386.2001-10-25.kitchen.ham.txt       Ham
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron2\ham\2416.2000-09-04.kaminski.ham.txt      Ham
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron6\spam\5119.2005-06-03.BG.spam.txt         Spam
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron6\spam\5045.2005-05-28.BG.spam.txt         Spam
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron1\ham\3892.2001-03-21.farmer.ham.txt        Ham
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron2\ham\4637.2001-03-06.kaminski.ham.txt      Ham
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron3\spam\0688.2004-09-30.BG.spam.txt         Spam
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron3\spam\3352.2005-02-28.BG.spam.txt         Spam
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron4\spam\2623.2004-10-07.GP.spam.txt         Spam
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron5\spam\3757.2005-07-07.SA_and_HP.spam.txt  Spam
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron4\spam\5841.2005-08-18.GP.spam.txt         Spam
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron4\ham\1702.2001-07-30.williams.ham.txt      Ham
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron2\spam\5616.2005-07-20.SA_and_HP.spam.txt  Spam
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron2\spam\0619.2002-07-19.SA_and_HP.spam.txt  Spam
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron6\spam\5379.2005-06-21.BG.spam.txt         Spam
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron2\ham\3747.2000-12-18.kaminski.ham.txt      Ham
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron3\ham\1387.2001-07-02.kitchen.ham.txt       Ham
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron1\ham\4762.2001-07-18.farmer.ham.txt        Ham
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron5\spam\4726.2005-07-19.SA_and_HP.spam.txt  Spam
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron6\ham\4922.2001-11-01.lokay.ham.txt         Ham
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron4\spam\0920.2004-04-20.GP.spam.txt         Spam
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron2\spam\0002.2001-05-25.SA_and_HP.spam.txt  Spam
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron4\spam\3581.2004-12-17.GP.spam.txt         Spam
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron1\spam\4314.2005-04-19.GP.spam.txt         Spam
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron3\ham\0067.2001-02-26.kitchen.ham.txt       Ham
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron3\ham\4469.2001-12-07.kitchen.ham.txt       Ham
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           text
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron4\spam\1306.2004-05-29.GP.spam.txt                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            Subject: re : are you still online ?click here to be removed
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron4\spam\0347.2004-02-05.GP.spam.txt                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                Subject: hiif youarepayingmore than3 . 6 %on yourmortgage ,we cansaveyoumoney ! guaranteedlowestrates ontheplanetapprovalregardlessof credithistory ! start savingtodayshow me thelowestratesto stopreceivingoffers here
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron6\spam\2646.2005-01-11.BG.spam.txt                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        Subject: urgenthi , i hereby wish to inform you that i am interested to purchase your , pci cardteac cd - w 54 e cd - r / rw burner , sony sdt - 5000 dds 2 ( 4 / 8 gb ) dat drive , sony 15 cl dds dat cleaning tape . what is your best offer ? are you the real owner ? what is the condition ? payment will be by money order . dont worried yourself about the pick up . i will take care of that when payment is done . if its still available for sale , provide the details below with which the payment will be sent to . . . offeri look forward to read from you soonest . cheers _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ _ do you yahoo ! ? tired of spam ? yahoo ! mail has the best spam protection around http : / / mail . yahoo . com
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron2\ham\3439.2000-11-27.kaminski.ham.txt                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Subject: transmission roundtable meetingthe meeting will be held on december 8 , 2000 from 11 : 30 am to 1 : 00 pm inconference room eb 19 cl . box lunches will be served . your choices arelisted below :salads : roasted chicken cobb salad , grilled chicken caesar salad , classicchef saladsandwiches : turkey , roast beef , ham , chicken salad , tuna salad or clubsandwich . served on homemade white or wheat breadplease email your lunch choice to me by monday , december 4 , 2000 .thanks and regards ,anita dupont
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron3\ham\4567.2001-12-13.kitchen.ham.txt                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Subject: ask jeeveslouise ,for the record , ask jeeves was a better investment than enron !- dan
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron6\ham\3534.2001-05-02.lokay.ham.txt                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Subject: fw : capacity at rio puercofyi - rio puerco receipt point capacity increase !- - - - - original message - - - - -from : " whittaker , barbara " @ enron [ mailto : imceanotes - + 22 whittaker + 2 c + 20 barbara + 22 + 20 + 3 cbwhitta + 40 pnm + 2 ecom + 3 e + 40 enron @ enron . com ]sent : wednesday , may 02 , 2001 11 : 36 amto : lorraine lindberg ( e - mail )cc : fenton , mark ; cross , jimmy ; thompson , chuck ( gsc )subject : capacity at rio puercolorraine :pnm has installed its redonda # 2 compressor to boost the capacity at the transwestern / pnm rio puerco interconnect . please revise the operational capacity indicated on transwestern ' s ebb for deliveries from pnm into transwestern from 80 , 000 mmbtus to 110 , 000 mmbtus .thank you for your assistance .barbara whittaker
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron2\ham\0779.2000-03-19.kaminski.ham.txt     Subject: re : presentationwill do - - thank you very much .dawnfrom : dawn scovill , event coordinatordesigns event consultingdawn @ perfectmeeting . com- - - - - original message - - - - -from : vince j kaminskito :cc : ; vince j kaminski;sent : friday , march 17 , 2000 5 : 38 pmsubject : re : presentation>>> david ,>> i am leaving for vacation this weekend and i haven ' t received the copy ofyour> presentation yet .> the window during which i could make changes to my presentation is closingvery> fast . let ' s> do the following : i shall keep my presentation as is ( this means that ishall> use the copy of my> presentation i sent to dawn scovill and you this week ) . if there is anoverlap> between our presentations , so be it .>> dawn , please use the copy of my presentation i sent you earlier this week .>> vince>>> - - - - - - - - - - - - - - - - - - - - - - forwarded by vince j kaminski / hou / ect on 03 / 17 / 200004 : 33> pm - - - - - - - - - - - - - - - - - - - - - - - - - - ->>> vince j kaminski> 03 / 16 / 2000 08 : 02 am>> to : " dawn scovill " @ enron> cc : sobotkad @ kochind . com , vince j kaminski / hou / ect @ ect> subject : re : presentation ( document link : vince j kaminski )>> dawn ,>> i met david sobotka from koch this morning and we talked aboutcoordinating our> presentations .> this means there will be changes intended to avoid overlaps . sorry forthat . the> portions of my presentation> will survive ( those about valuation paradigms ) and i shall add a few morepages> on accounting treatment of weather derivatives> plus more specific examples . david will cover primarily market evolution +plus> examples of some> standard structures , and we shall both give more interesting examples of> specific deals executed by our companies .>> i shall send you an updated version of my part next week . let me know whatthe> deadline is .>> vince>>>> " dawn scovill " on 03 / 14 / 2000 07 : 53 : 47 am>> to : " vince j kaminski "> cc :> subject : re : presentat...
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron6\spam\2574.2005-01-07.BG.spam.txt                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Subject: lonely girls who are home for new year100 % free adult personalsyou need to get laid ! ! ! ! ! ! ! ! ! ! !we can help .http : / / dating . viewing . atreal profiles of people in your area thatjust want sex !100 % free ! ! ! ! !http : / / dating . viewing . at- - - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -remove your self
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron6\ham\0381.2000-07-14.lokay.ham.txt                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 Subject: anadarko and union pacific resources merged company will be namedanadarko petroleumshareholders of anadarko petroleum and union pacific resources voted toapprove a$ 5 . 4 billion merger of the two companies yesterday . the merger calls for uprshareholdersto receive 0 . 455 shares of anadarko common stock for each of their uprshares . anadarkoshareholders also voted to increase the size of the company ' s board to 15members fromnine . the combined company will be named anadarko petroleum .
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron5\spam\0498.2002-07-16.SA_and_HP.spam.txt  Subject: ~ ~ 80 to 95 % below wholesale 28534buy products70 to 80 %below wholesalenew , and in quantities you needa single unit , a pallet ,or a truckload1 . do you consider yourself financially secure ?2 . are you still looking for a very real business that can provide you andyour family with the lifestyle you desire and deserve ? or , just a secondincome in your spare time ?3 . would you invest $ 66 . 50 ( a 25 % discount off of our regular price of$ 99 . 95 during this limited time promotion . ) in a business that could make youfinancially secure ?if so , read on :this is not a get rich quick scheme , but , it is a way for you to get intoa business with a minimal investment and , may be your first step towards arewarding first , or second income . for the longest time , only those , who wereable to make large investments were able to take advantage of this type of abusiness . we have made it possible for everyone to do it , and at a priceeveryone can afford .corporate america has conditioned us to believe that security comes fromemployment . yet layoffs are hitting an all time high , major corporations arefailing and we hope to never become the victims of this downsizing , careerburn out , illness or injury .there was a time , when finding another job was not a problem , but today ,the frightening reality for a lot of people is that theplastic in their wallets determines the quality of their lives .the hard facts show that our economy has moved from the industrial ageinto the information , service and retail age . no longer can you depend on thecorporation to provide your family with the security you seek .if you are tired of living from paycheck to paycheck , and are willing towork a few hours per week , than this may be for you .please read further :we will show you how you can buy , new , not out of date , products for pennieson the wholesale dollar . we will not just send alist , or catalog of where you can buy , but actual point and click databasewith hy...
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron4\spam\5966.2005-09-03.GP.spam.txt                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Subject: fw : rolex repllcas - $ 199hi , get these replica watches from $ 199 :1 . roiex2 . cartier3 . breitiing4 . a . iange sohne5 . patek phiiippe6 . bvigari7 . franck muiier8 . omega9 . tag heuerhttp : / / www . mrut . com / re / aug /you can order a gift boxset if you want .thanks ,desmond celena- - - - - original message - - - - -from : desmond celenato : desmond celenasent : fri , 02 sep 2005 15 : 13 : 54 - 0800subject : fw : rolex repllcas - $ 199have a look ?- http : / / www . mrut . com / re / aug /do you already one ?- http : / / www . mrut . com / z . php
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron4\ham\5225.2002-01-23.williams.ham.txt                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Subject: schedule crawler : hourahead failurestart date : 1 / 23 / 02 ; hourahead hour : 14 ; hourahead schedule download failed . manual intervention required .log messages :parsing file - - > > o : \ portland \ westdesk \ california scheduling \ iso final schedules \ 2002012314 . txterror : dbcaps 97 data : cannot perform this operation on a closed database! ! ! unknown database .alias : dbcaps 97 data! ! ! unknown database .alias : dbcaps 97 data! ! ! unknown database .alias : dbcaps 97 dataerror : dbcaps 97 data : cannot perform this operation on a closed database! ! ! unknown database .alias : dbcaps 97 data! ! ! unknown database .alias : dbcaps 97 data! ! ! unknown database .alias : dbcaps 97 dataerror : dbcaps 97 data : cannot perform this operation on a closed database! ! ! unknown database .alias : dbcaps 97 data! ! ! unknown database .alias : dbcaps 97 dataerror : dbcaps 97 data : cannot perform this operation on a closed databaseerror : dbcaps 97 data : cannot perform this operation on a closed databaseerror : dbcaps 97 data : cannot perform this operation on a closed database! ! ! unknown database .alias : dbcaps 97 data! ! ! unknown database .alias : dbcaps 97 data! ! ! unknown database .alias : dbcaps 97 data! ! ! unknown database .alias : dbcaps 97 data! ! ! unknown database .alias : dbcaps 97 data! ! ! unknown database .alias : dbcaps 97 dataerror : dbcaps 97 data : cannot perform this operation on a closed database
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron2\ham\1669.2000-06-30.kaminski.ham.txt                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Subject: lance cunninghamvince :i have left a message with teresa and have sent the following terse note tolance to let him know that we are moving .as we discussed , i asked teresa to offer 90 k + 10 k signing bonus .regards ,grant- - - - - - - - - - - - - - - - - - - - - - forwarded by grant masson / hou / ect on 06 / 30 / 2000 11 : 21am - - - - - - - - - - - - - - - - - - - - - - - - - - -enron north america corp .from : grant masson 06 / 30 / 2000 11 : 21 amto : lbcunningham @ mail . utexas . educc :subject : enronlance :i am going on vacation tomorrow , but i wanted to get in touch with you beforei left .i have asked hr to extend an offer to you . teresa bien should be sending youan offer letter via fedex . of course , with the july 4 th weekend , i ' m not surewhen you will get it .if you have questions , i suggest that you call vince kaminski at 713 8533848 .regards ,grant masson .
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron3\ham\4653.2001-12-20.kitchen.ham.txt                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     Subject: splash page textok - here ' s the sort of thing i am thinking of ( still needs kal ' s magic ) .i suspect you were thinking of a pop - up notice . given that we aren ' t really showing anything on enrononline at the moment , i suggest we take down enrononline entirely and replace it with a splash page which says something like the following :coming soonenron is working with potential industry partners to assemble a new venture which will combine enron ' s trading and market - making expertise with the financial strength and reliability of an a rated entity .upon formation of this new company , we anticipate that we will be able to announce the launch of a new trading platform for north american gas and power , providing services similar to those previously available on enrononline .please check back with this site for future updates on plans for the new trading platform .what do you think ?
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron4\spam\5363.2005-06-06.GP.spam.txt                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Subject: impress your wifehi there ,try our revolutionary product , c _ i _ a _ l _ i _ s soft tabs . newimproved formula makes it even better .cialis soft tabs is the new impotence treatment drug that everyoneis talking about . cialis acts up to 36 hours , compare this toonly two or three hours of viagra action ! the active ingredient istadalafil , same as in brand cialis .simply dissolve half a pill under your tongue , 10 min beforeintercourse for the best erections you ' ve ever had ! cialis alsohave less sidebacks ( you can drive or mix alcohol drinks withthem ) . no prior prescription is needed .worldwide shipping , thousands of happy customers !you can get it at : http : / / zigzagging . net / soft /world rx direct can bring you quality generic drugs for afraction of the cost of the expensive brand name equivalents .order our tadalafil pills today and save 80 % . we ship worldwide ,and currently supply to over 1 million customers globally ! wealways strive to bring you the cheapest prices .no thanks : http : / / zigzagging . net / rr . php
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron2\spam\4834.2005-07-16.SA_and_HP.spam.txt                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Subject: chheep medzhow to save o vacationist n your medlcations over 70 % .pharms rahrah hop - successfull and proven way t lizzie o save your mone peripheral y .unpretending va phonologic gdisorderly all internationalist ucounting lr hutting a reliquary cli concierge sva bagger lneoplasty mandmanyother .best prlces toddle .worldwide shlpp vulcanite lng .easy order teethe form .t nominal otal confidentiaiity .250 , 000 satisfied customer superette s .order toda zygoma y and save !
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron3\ham\2520.2001-09-14.kitchen.ham.txt                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Subject: warning re : colin goodwas originally passed to me from you .is a time - waster and is threatening to call you again .see me if you want details .dave
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron3\ham\1977.2001-08-10.kitchen.ham.txt      Subject: fw : i want my mtv ?here is that song created to the music of mtv and all about eol .bt- - - - - original message - - - - -from : ward , kim s ( houston )sent : friday , august 10 , 2001 9 : 35 amto : ' kwardl @ houston . rr . com ' ; tycholiz , barry ; ermis , frank ; reitmeyer , jay ; arnold , john ; vann , suzanne ; polsky , philsubject : fw : i want my mtv ?- - - - - original message - - - - -from : " melissa reese " @ enron [ mailto : imceanotes - + 22 melissa + 20 reese + 22 + 20 + 3 cmreese + 40 cmsenergy + 2 ecom + 3 e + 40 enron @ enron . com ]sent : friday , august 10 , 2001 8 : 57 amto : ward , kim s ( houston )subject : fw : i want my mtv ?funny- - - - - - - - - - - - - - - - - - - - - - forwarded by melissa reese / mst / cms on 08 / 10 / 200109 : 00 am - - - - - - - - - - - - - - - - - - - - - - - - - - -corey ayers08 / 10 / 2001 08 : 39 amto : sean e sasko / mst / cms @ cms , eric s crabtree / mst / cms @ cms , tim lspurlin / mst / cms @ cms , patrick j grimes / mst / cms @ cms , curt jlizzi / mst / cms @ cms , chadd moore / mst / cms @ cms , ken skaer / mst / cms @ cms ,scott biscoe / mst / cms @ cms , melisa d richardson / mst / cms @ cms , melissareese / mst / cms @ cmscc :subject : fw : i want my mtv ?this fits our conversation this morning- - - - - - - - - - - - - - - - - - - - - - forwarded by corey ayers / mst / cms on 08 / 10 / 2001 08 : 41am - - - - - - - - - - - - - - - - - - - - - - - - - - -" johnson , todd " on 08 / 10 / 2001 08 : 33 : 39 amto : " ' cayers @ cmsenergy . com ' "cc : " ' stouchstone @ natsource . com ' "subject : fw : i want my mtv ?i want my , i want my eoli want my , i want my eoli want my , i want my eoli want my , i want my eolnow look at them market makers ' s , that ' s the way you do ityou buy the nat gas on that eolthat ain ' t tradin ' , that ' s the way you do itbuying for nothin ' and your commissions for freenow that ain ' t tradin ' , that ' s the way you do itlemme tell ya , them guys ain ' t dumbm...
# ...
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron6\ham\4922.2001-11-01.lokay.ham.txt                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               Subject: phillip ' s new wellbelow is a new well phillip ' s has completed in the panhandle that appearsto be very close to a tw pipeline . would you be the person i woulddiscuss a possible interconnect with tw ?trumbell # 3 , morrow test . sherman county , texas . 999 ' fnl & 974 ' fwl ,section 246 - blklt - t & no survey . perforated morrow interval . well kick offand flowed ~ 8 . 5 mmcfd , fp 625 psi . shut in well w / 1025 psi atwellhead . shut well for pipeline connect . recommend high pressure connect .thanks ,barry stuartphillips petroleum company713 . 669 . 7361713 . 669 . 7358 faxblstuar @ ppco . com
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron4\spam\0920.2004-04-20.GP.spam.txt                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  Subject: huroncotton , /75 % off for all new softwares .windowxp , photoshop , window 2003 . . . etcmoretimeworn , summoning in turn .
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron2\spam\0002.2001-05-25.SA_and_HP.spam.txt                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          Subject: fw : this is the solution i mentioned lscoothank you ,your email address was obtained from a purchased list ,reference # 2020 mid = 3300 . if you wish to unsubscribefrom this list , please click here and enteryour name into the remove box . if you have previously unsubscribedand are still receiving this message , you may email our abusecontrol center , or call 1 - 888 - 763 - 2497 , or write us at : nospam ,6484 coral way , miami , fl , 33155 " .  2002web credit inc . all rights reserved .
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron4\spam\3581.2004-12-17.GP.spam.txt                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   Subject: re : account # 15744374 ghello ,we sent you an email a while ago , because you now qualifyfor a much lower rate based on the biggest rate drop in years .you can now get $ 250 , 000 for as little as $ 515 a month !bad credit ? doesn ' t matter , low rates are fixed no matter what !follow this link to process your application and a 24 hour approval :best regards ,hershel vanghttp : / / www . mrrefinancing . net / x / st . html
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron1\spam\4314.2005-04-19.GP.spam.txt         Subject: cardiology , radiology , 7 , 000 senior hospitals , , 172 , 000 senior hospital administrators and doctors .7 , 000 hospitals , 172 , 000 senior hospital administrators .pre _ publication offer of $ 247 . 00 ( reg . $ 1 , 299 ) .the new american hospital marketing guide is an extremelycost - effective way of increasing your marketing efforts .david stanford , chicago , il .in response to numerous inquiries from healthcare marketers ,healthline publications corp . is introducing the new americanhospital marketing guide . the new guide is an attempt toassist healthcare professionals to target hospitaldecision - makers throughout the country . the guide includesadministrators in hospitals in the united states such asceos , cfos , directors ( surgery , nursing , purchasing , etc . )in addition to mailing addresses , fax and phone numbers , thepublication includes important hospital stats such as numberof beds , hospital type , hospital number and staff size .in a rapidly - changing industry , current healthcare informationis an invaluable resource to businesses and organizations .the new american hospital marketing guide includes comprehensiveinformation on more than 7 , 000 hospitals and 172 , 000administrators . it is the most extensive and database of keydecision - makers in the health care market .each record is indexed by such features as name , address , phone andfax . the database is available in excel format on cd rom . it isdesigned for mailing lists and merges . the data can be selected bystate or other criteria such as type of practice . it can be used onan unlimited basis .if you are interested in identifying and contacting hospitaldecision - makers most likely to benefit from your product orservice , the new american hospital guide will save you timeand money .to order the new american hospital guide , simply fill outthe information below andfax it to 416 760 - 3763 ( tel : 416 760 - 3762 ) .bonus offer : new customer offer . order now and rece...
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron3\ham\0067.2001-02-26.kitchen.ham.txt                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      Subject: hpl closingplease find the attached status update for the hpl transaction . if you have any questions please contact me .thanks ,brian
# C:\Users\Manolis\Desktop\lab2_TA\Enron_dataset\enron3\ham\4469.2001-12-07.kitchen.ham.txt                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             Subject: fw :- - - - - original message - - - - -from : oquinn , karisent : friday , december 07 , 2001 3 : 49 pmto : slone , jeaniesubject : fw :- - - - - original message - - - - -from : richter , bradsent : friday , december 07 , 2001 11 : 51 amto : fitzpatrick , amycc : oquinn , karisubject : fw :amy - -attached is an eol bonus matrix per louise ' s request . i haven ' t changed any of the numbers from the basic calculation done by kari . for clarification , kara lauer is a sr . specialist . call me if you have questions .brad richter- - - - - original message - - - - -from : oquinn , karisent : friday , december 07 , 2001 10 : 52 amto : richter , bradsubject : fw :attached is the file w / add ' l info . according to our records , kara lauer is a sr spec ; however , the file you sent indicates she is a spec . please read the detailed info at the bottom of the spreadsheet which indicates how the recommended bonuses were derived .kari oquinn713 - 853 - 9134- - - - - original message - - - - -from : richter , bradsent : friday , december 07 , 2001 9 : 40 amto : oquinn , karisubject :here is the file . please call my cell phone if you have questions .thank you ,brad richter713 - 594 - 0220
#
# [33716 rows x 2 columns]

# %%
data.shape
data['label'].value_counts()
# Out:
# Spam    17171
# Ham     16545
# Name: label, dtype: int64

# %%
'''
Split dataset into train (70%) & test (30%)
Transform labels to one hot encoding 
'''

import itertools
from sklearn.model_selection import train_test_split
from sklearn import preprocessing

train, test = train_test_split(data, test_size = 0.3,random_state=1596)

X_train = list(itertools.chain.from_iterable(train[['text']].values.tolist()))
X_test = list(itertools.chain.from_iterable(test[['text']].values.tolist()))

y_train = list(itertools.chain.from_iterable(train[['label']].values.tolist()))
le = preprocessing.LabelEncoder()
le.fit(y_train)
y_train = le.transform(y_train)
y_test = le.transform(list(itertools.chain.from_iterable(test[['label']].values.tolist())))

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import pprint

#Use unigram & bi-gram tf*idf features
vectorizer = TfidfVectorizer(ngram_range=(1, 2), max_features = 5000,sublinear_tf=True)

X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tfidf = vectorizer.transform(X_test)

pprint.pprint(vectorizer.get_feature_names())
# Out:
# ['00',
#  '00 00',
#  '00 am',
#  '00 pm',
#  '000',
#  '000 00',
#  '000 000',
#  '000 enron',
#  '000 for',
#  '000 mmbtu',
#  '01',
#  '01 2001',
#  '01 hourahead',
#  '01enron',
#  '02',
#  '02 2001',
#  '02 hourahead',
#  '03',
#  '04',
#  '05',
#  '06',
#  '07',
#  '07 2000',
#  '08',
#  '09',
#  '10',
#  '10 00',
#  '10 000',
#  '10 2000',
#  '10 30',
#  '10 57',
#  '100',
#  '100 000',
#  '1000',
#  '101',
#  '105',
#  '11',
#  '11 2000',
#  '11 2001',
#  '11 30',
#  '12',
#  '12 00',
#  '12 2001',
#  '120',
#  '125',
#  '13',
#  '13 2001',
#  '14',
#  '140',
#  '15',
#  '150',
#  '16',
#  '16 2001',
#  '161',
#  '1618',
#  '17',
#  '18',
#  '19',
#  '19 2001',
#  '19 jul',
#  '1933',
#  '1933 and',
#  '1934',
#  '1934 any',
#  '1995',
#  '1997',
#  '1998',
#  '1999',
#  '20',
#  '20 000',
#  '200',
#  '2000',
#  '2000 01',
#  '2000 02',
#  '2000 03',
#  '2000 04',
#  '2000 05',
#  '2000 08',
#  '2000 09',
#  '2000 10',
#  '2000 11',
#  '2000 12',
#  '2000 dow',
#  '2001',
#  '2001 01',
#  '2001 02',
#  '2001 03',
#  '2001 04',
#  '2001 08',
#  '2001 09',
#  '2001 10',
#  '2001 11',
#  '2001 12',
#  '2001 dow',
#  '2001 the',
#  '2001dow',
#  '2001dow jones',
#  '2001reuters',
#  '2001reuters english',
#  '2001the',
#  '2002',
#  '2003',
#  '2004',
#  '2005',
#  '2005 10',
#  '21',
#  '21 2001',
#  '21 of',
#  '212',
#  '215',
#  '22',
#  '229',
#  '23',
#  '23 2001',
#  '24',
#  '24 2001',
#  '24 hours',
#  '249',
#  '25',
#  '25 000',
#  '25 2001',
#  '250',
#  '26',
#  '26 2001',
#  '27',
#  '27 of',
#  '28',
#  '28 2000',
#  '281',
#  '29',
#  '30',
#  '30 000',
#  '30 2001',
#  '30 am',
#  '30 pm',
#  '300',
#  '31',
#  '31 st',
#  '32',
#  '33',
#  '34',
#  '345',
#  '35',
#  '36',
#  '36 hours',
#  '37',
#  '38',
#  '39',
#  '40',
#  '400',
#  '41',
#  '42',
#  '43',
#  '44',
#  '45',
#  '46',
#  '464',
#  '47',
#  '48',
#  '49',
#  '50',
#  '50 000',
#  '500',
#  '500 000',
#  '51',
#  '512',
#  '52',
#  '53',
#  '54',
#  '55',
#  '56',
#  '57',
#  '58',
#  '59',
#  '60',
#  '60 pills',
#  '600',
#  '61',
#  '62',
#  '63',
#  '63 161',
#  '64',
#  '646',
#  '65',
#  '650',
#  '66',
#  '67',
#  '69',
#  '69 63',
#  '70',
#  '700',
#  '713',
#  '713 646',
#  '713 853',
#  '72',
#  '74',
#  '75',
#  '750',
#  '76',
#  '78',
#  '79',
#  '80',
#  '80 adobe',
#  '800',
#  '84',
#  '85',
#  '853',
#  '86',
#  '87',
#  '8859',
#  '888',
#  '89',
#  '90',
#  '90 pills',
#  '92',
#  '95',
#  '96',
#  '97',
#  '97 data',
#  '97 dataerror',
#  '971',
#  '98',
#  '99',
#  'aa',
#  'ability',
#  'ability to',
#  'able',
#  'able to',
#  'about',
#  'about billion',
#  'about enron',
#  'about it',
#  'about its',
#  'about the',
#  'about this',
#  'about your',
#  'above',
#  'absolutely',
#  'ac',
#  'accept',
#  'acceptance',
#  'acceptance of',
#  'accepted',
#  'access',
#  'access to',
#  'according',
#  'according to',
#  'account',
#  'accounting',
#  'accounts',
#  'accuracy',
#  'accuracy or',
#  'achieve',
#  'acquire',
#  'acquired',
#  'acquisition',
#  'acquisition of',
#  'acquisitions',
#  'acrobat',
#  'across',
#  'act',
#  'act and',
#  'act of',
#  'action',
#  'action may',
#  'actions',
#  'actions may',
#  'active',
#  'activities',
#  'activity',
#  'acts',
#  'actual',
#  'actual results',
#  'actually',
#  'actuals',
#  'ad',
#  'add',
#  'added',
#  'adding',
#  'addition',
#  'addition to',
#  'additional',
#  'additional information',
#  'additionally',
#  'address',
#  'addressed',
#  'addresses',
#  'adds',
#  'administration',
#  'adobe',
#  'adobe photoshop',
#  'adobe premiere',
#  'adult',
#  'advance',
#  'advanced',
#  'advantage',
#  'advantage of',
#  'advertisement',
#  'advertisement and',
#  'advertising',
#  'advice',
#  'advice from',
#  'advise',
#  'advised',
#  'advised that',
#  'advises',
#  'advisor',
#  'aep',
#  'affairs',
#  'affect',
#  'affiliate',
#  'affiliated',
#  'affiliates',
#  'affordable',
#  'africa',
#  'after',
#  'after the',
#  'afternoon',
#  'again',
#  'against',
#  'against the',
#  'age',
#  'agencies',
#  'agency',
#  'agenda',
#  'agent',
#  'aggressive',
#  'ago',
#  'agree',
#  'agreed',
#  'agreed to',
#  'agreement',
#  'agreement with',
#  'agreements',
#  'ahead',
#  'ail',
#  'aimee',
#  'air',
#  'al',
#  'alert',
#  'alex',
#  'ali',
#  'ali duty',
#  'alias',
#  'alias dbcaps',
#  'align',
#  'all',
#  'all information',
#  'all of',
#  'all rights',
#  'all the',
#  'all your',
#  'allegheny',
#  'allen',
#  'allocated',
#  'allocation',
#  'allow',
#  'allowed',
#  'allows',
#  'almost',
#  'alone',
#  'along',
#  'along with',
#  'already',
#  'also',
#  'also be',
#  'also have',
#  'alternative',
#  'although',
#  'always',
#  'am',
#  'am not',
#  'am to',
#  'america',
#  'america corp',
#  'american',
#  'americas',
#  'ami',
#  'ami chokshi',
#  'amid',
#  'among',
#  'among the',
#  'amount',
#  'amount of',
#  'amounts',
#  'amto',
#  'amto vince',
#  'amy',
#  'an',
#  'an additional',
#  'an analyst',
#  'an email',
#  'an enron',
#  'an inherent',
#  'an offer',
#  'an officer',
#  'analysis',
#  'analyst',
#  'analysts',
#  'ancillary',
#  'ancillary schedules',
#  'and',
#  'and all',
#  'and also',
#  'and am',
#  'and an',
#  'and any',
#  'and are',
#  'and as',
#  'and business',
#  'and can',
#  'and ceo',
#  'and chief',
#  'and company',
#  'and do',
#  'and enron',
#  'and even',
#  'and exchange',
#  'and fax',
#  'and financial',
#  'and for',
#  'and gas',
#  'and get',
#  'and has',
#  'and have',
#  'and he',
#  'and his',
#  'and how',
#  'and if',
#  'and in',
#  'and is',
#  'and it',
#  'and its',
#  'and let',
#  'and make',
#  'and many',
#  'and may',
#  'and more',
#  'and my',
#  'and names',
#  'and natural',
#  'and new',
#  'and no',
#  'and not',
#  'and or',
#  'and other',
#  'and others',
#  'and our',
#  'and paste',
#  'and power',
#  'and projections',
#  'and risk',
#  'and save',
#  'and section',
#  'and see',
#  'and sell',
#  'and services',
#  'and should',
#  'and some',
#  'and subscribers',
#  'and that',
#  'and the',
#  'and their',
#  'and then',
#  'and there',
#  'and they',
#  'and this',
#  'and to',
#  'and uncertainties',
#  'and was',
#  'and we',
#  'and web',
#  'and what',
#  'and will',
#  'and would',
#  'and you',
#  'and your',
#  'andersen',
#  'andrew',
#  'andrew fastow',
#  'andy',
#  'angeles',
#  'anita',
#  'anjam',
#  'anne',
#  'announce',
#  'announced',
#  'announced today',
#  'announcement',
#  'announces',
#  'annual',
#  'another',
#  'answer',
#  'anti',
#  'anticipated',
#  'anticipates',
#  'anticipates estimates',
#  'any',
#  'any kind',
#  'any of',
#  'any other',
#  'any questions',
#  'any statements',
#  'any time',
#  'anybody',
#  'anyone',
#  'anything',
#  'anytime',
#  'anywhere',
#  'aol',
#  'aol com',
#  'appear',
#  'appears',
#  'application',
#  'applications',
#  'applied',
#  'apply',
#  'appreciate',
#  'appreciate your',
#  'approach',
#  'appropriate',
#  'approval',
#  'approved',
#  'approved for',
#  'approximately',
#  'april',
#  'are',
#  'are also',
#  'are available',
#  'are based',
#  'are being',
#  'are currently',
#  'are going',
#  'are in',
#  'are interested',
#  'are just',
#  'are looking',
#  'are made',
#  'are not',
#  'are now',
#  'are on',
#  'are pleased',
#  'are ready',
#  'are still',
#  'are the',
#  'are you',
#  'area',
#  'areas',
#  'arm',
#  'around',
#  'around the',
#  'arrange',
#  'arrangement',
#  'arrangements',
#  'art',
#  'article',
#  'as',
#  'as an',
#  'as any',
#  'as enron',
#  'as follows',
#  'as information',
#  'as it',
#  'as long',
#  'as low',
#  'as much',
#  'as of',
#  'as one',
#  'as part',
#  'as possible',
#  'as projects',
#  'as result',
#  'as soon',
#  'as such',
#  'as the',
#  'as they',
#  'as to',
#  'as we',
#  'as well',
#  'as with',
#  'as you',
#  'asap',
#  'asia',
#  'ask',
#  'asked',
#  'asking',
#  'assembly',
#  'asset',
#  'assets',
#  'assets and',
#  'assist',
#  'assistance',
#  'assistant',
#  'associate',
#  'associated',
#  'associated with',
#  'associates',
#  'association',
#  'assume',
#  'assumptions',
#  'assumptions or',
#  'assurance',
#  'at',
#  'at 00',
#  'at 713',
#  'at all',
#  'at any',
#  'at enron',
#  'at http',
#  'at least',
#  'at our',
#  'at the',
#  'at this',
#  'at your',
#  'attached',
#  'attached file',
#  'attached is',
#  'attached to',
#  'attachments',
#  'attacks',
#  'attempt',
#  'attend',
#  'attention',
#  'attorney',
#  'auction',
#  'audit',
#  'aug',
#  'august',
#  'australia',
#  'authority',
#  'authorized',
#  'auto',
#  'automatically',
#  'availability',
#  'available',
#  'available for',
#  'available to',
#  'average',
#  'avoid',
#  'award',
#  'awarded',
#  'awarded no',
#  'aware',
#  'aware of',
#  'away',
#  'away from',
#  'back',
#  'back to',
#  'background',
#  'bad',
#  'balance',
#  'balance sheet',
#  'ballot',
#  'bandwidth',
#  'bank',
#  'bank account',
#  'bank of',
#  'banking',
#  'bankruptcy',
#  'banks',
#  'barry',
#  'base',
#  'based',
#  'based on',
#  'basic',
#  'basin',
#  'basis',
#  'batch',
#  'baylor',
#  'bbb',
#  'bcf',
#  'be',
#  'be able',
#  'be advised',
#  'be an',
#  'be available',
#  'be aware',
#  'be completed',
#  'be considered',
#  'be construed',
#  'be done',
#  'be for',
#  'be forward',
#  'be happy',
#  'be held',
#  'be identified',
#  'be in',
#  'be interested',
#  'be made',
#  'be no',
#  'be on',
#  'be removed',
#  'be the',
#  'be understood',
#  'be used',
#  'be very',
#  'beach',
#  'became',
#  'because',
#  'because it',
#  'because of',
#  'because the',
#  'because you',
#  'beck',
#  'become',
#  'bed',
#  'been',
#  'been approved',
#  'been completed',
#  'been made',
#  'before',
#  'before deciding',
#  'before the',
#  'before you',
#  'began',
#  'begin',
#  'beginning',
#  'behalf',
#  'behalf of',
#  'behind',
#  'being',
#  'belden',
#  'beliefs',
#  'beliefs plans',
#  'believe',
#  'believe that',
#  'believes',
#  'believes understands',
#  'below',
#  'below and',
#  'below for',
#  'ben',
#  'beneficiary',
#  'benefit',
#  'benefits',
#  'best',
#  'best regards',
#  'beth',
#  'better',
#  'between',
#  'between the',
#  'beyond',
#  'bid',
#  'big',
#  'bigger',
#  'biggest',
#  'bill',
#  'billion',
#  'billion in',
#  'billion of',
#  'bills',
#  'bit',
#  'biz',
#  'black',
#  'blackberry',
#  'blood',
#  'bloomberg',
#  'blue',
#  'bn',
#  'board',
#  'board of',
#  'bob',
#  'body',
#  'bond',
#  'bonds',
#  'bonus',
#  'book',
#  'books',
#  'boost',
#  'boost your',
#  'border',
#  'both',
#  'both the',
#  'bottom',
#  'bought',
#  'box',
#  'bra',
#  'brad',
#  'brand',
#  'brand name',
#  'break',
#  'breaking',
#  'breaking news',
#  'brenda',
#  'brent',
#  'brian',
#  'bridge',
#  'brief',
#  'bring',
#  'british',
#  'broadband',
#  'broadcast',
#  'broker',
#  'brought',
#  'brown',
#  'browser',
#  'bruce',
#  'bryan',
#  'budget',
#  'build',
#  'building',
#  'built',
#  'bulk',
#  'bush',
#  'business',
#  'business and',
#  'business in',
#  'business unit',
#  'business with',
#  'businesses',
#  'busy',
#  'but',
#  'but can',
#  'but it',
#  'but not',
#  'but the',
#  'but we',
#  'button',
#  'buy',
#  'buyer',
#  'buyers',
#  'buying',
#  'by',
#  'by enron',
#  'by mail',
#  'by statements',
#  'by the',
#  'by vince',
#  'ca',
#  'cable',
#  'cal',
#  'calendar',
#  'calger',
#  'california',
#  'california scheduling',
#  'call',
#  'call me',
#  'call you',
#  'called',
#  'calling',
#  'calls',
#  'calpine',
#  'came',
#  'campaign',
#  'can',
#  'can be',
#  'can do',
#  'can get',
#  'can help',
#  'can make',
#  'can not',
#  'can you',
#  'canada',
#  'canadian',
#  'candidate',
#  'candidates',
#  'cannot',
#  'cannot be',
#  'cannot perform',
#  'cap',
#  'capacity',
#  'capital',
#  'car',
#  'card',
#  'cards',
#  'care',
#  'career',
#  'carefully',
#  'carlos',
#  'carol',
#  'carry',
#  'case',
#  'cases',
#  'cash',
#  'cash flow',
#  'category',
#  'cause',
#  'caused',
#  'cc',
#  'cc subject',
#  'cd',
#  'cds',
#  'ce',
#  'cec',
#  'cell',
#  'cent',
#  'center',
#  'central',
#  'cents',
#  'cents to',
#  'ceo',
#  'ceo of',
#  'cera',
#  'cera com',
#  'certain',
#  'certain actions',
#  'certainly',
#  'cfo',
#  'chair',
#  'chairman',
#  'chairman and',
#  'chance',
#  'chance to',
#  'change',
#  'change in',
#  'change the',
#  'changed',
#  'changes',
#  'changes in',
#  'changes to',
#  'changing',
#  'chapter',
#  'charge',
#  'charges',
#  'charles',
#  'charset',
#  'chase',
#  'cheap',
#  'check',
#  'check out',
#  'chevrontexaco',
#  'chicago',
#  'chief',
#  'chief executive',
#  'chief financial',
#  'child',
#  'children',
#  'china',
#  'chinese',
#  'choice',
#  'chokshi',
#  'choose',
#  'chris',
#  'christian',
#  'christie',
#  'christopher',
#  'cialis',
#  'cindy',
#  'citigroup',
#  'city',
#  'claim',
#  'claimed',
#  'claiming',
#  'claims',
#  'class',
#  'clean',
#  'clear',
#  'clearance',
#  'clearly',
#  'click',
#  'click here',
#  'click on',
#  'click the',
#  'clickhere',
#  'client',
#  'clients',
#  'close',
#  'close to',
#  'closed',
#  'closed database',
#  'closely',
#  'closing',
#  'club',
#  'co',
#  'coal',
#  'coast',
#  'coastal',
#  'code',
#  'collapse',
#  'collateral',
#  'colleagues',
#  'college',
#  'color',
#  'column',
#  'com',
#  'com and',
#  'com cc',
#  'com on',
#  'com sent',
#  'combination',
#  'combined',
#  'comcc',
#  'comcc subject',
#  'comcopyright',
#  'comcopyright 2000',
#  'come',
#  'come to',
#  'comes',
#  'coming',
#  'comment',
#  'comments',
#  'commerce',
#  'commercial',
#  'commercial paper',
#  'commission',
#  'commitment',
#  'committed',
#  'committee',
#  'commodities',
#  'commodity',
#  'common',
#  'communicate',
#  'communication',
#  'communications',
#  'communications enron',
#  'community',
#  'companies',
#  'companies are',
#  'companies that',
#  'company',
#  'company and',
#  'company has',
#  'company in',
#  'company inc',
#  'company is',
#  'company said',
#  'company that',
#  'company the',
#  'company to',
#  'compare',
#  'compared',
#  'compensated',
#  'compensation',
#  'competition',
#  'competitive',
#  'competitors',
#  'complete',
#  'complete the',
#  'completed',
#  'completely',
#  'completion',
#  'complex',
#  'compliance',
#  'compliance with',
#  'computer',
#  'computron',
#  'computron me',
#  'comsubject',
#  'con',
#  'concept',
#  'concern',
#  'concerned',
#  'concerning',
#  'concerns',
#  'conditions',
#  'conduct',
#  'conference',
#  'conference call',
#  'confidence',
#  'confidence in',
#  'confidential',
#  'confidentiality',
#  'confirm',
#  'confirm your',
#  'confirmation',
#  'confirmed',
#  'conflict',
#  'conflict of',
#  'congratulations',
#  'congress',
#  'connection',
#  'consequently',
#  'consider',
#  'considered',
#  'considering',
#  'consistent',
#  'constitute',
#  'constitutes',
#  'construction',
#  'construed',
#  'construed as',
#  'consultation',
#  'consulting',
#  'consumer',
#  'consumers',
#  'contact',
#  'contact me',
#  'contact the',
#  'contact you',
#  'contact your',
#  'contacted',
#  'contacting',
#  'contacts',
#  'contain',
#  'contained',
#  'contained in',
#  'contains',
#  'contains forward',
#  'content',
#  'contents',
#  'contents of',
#  'continue',
#  'continue to',
#  'continued',
#  'continues',
#  'continues to',
#  'continuing',
#  'contract',
#  'contracts',
#  'control',
#  'controls',
#  'convenience',
#  'convenient',
#  'conversation',
#  'cooperation',
#  'coordinate',
#  'coordinator',
#  'copies',
#  'copy',
#  'copy and',
#  'copy of',
#  'copyright',
#  'copyright 2000',
#  'copyright 2001',
#  'core',
#  'corel',
#  'corp',
#  'corp and',
#  'corp enron',
#  'corp from',
#  'corporate',
#  'corporation',
#  'correct',
#  'correspondence',
#  'cost',
#  'cost of',
#  'costs',
#  'cotten',
#  'cotten hou',
#  'couid',
#  'could',
#  'could be',
#  'could cause',
#  'could have',
#  'could not',
#  'could or',
#  'could you',
#  'couldn',
#  'count',
#  'counterparties',
#  'counterparty',
#  'countries',
#  'country',
#  'couple',
#  'couple of',
#  'coupon',
#  'course',
#  'court',
#  'cover',
#  'coverage',
#  'create',
#  'created',
#  'creating',
#  'creative',
#  'credibility',
#  'credit',
#  'credit card',
#  'credit line',
#  'credit rating',
#  'creditors',
#  'crenshaw',
#  'crenshaw hou',
#  'crisis',
#  'critical',
#  'cross',
#  'crude',
#  'cs',
#  'cubic',
#  'cubic feet',
#  'current',
#  'current price',
#  'currently',
#  'curve',
#  'curves',
#  'custom',
#  'customer',
#  'customers',
#  'cut',
#  'cutting',
#  'da',
#  'dabhol',
#  'daily',
#  'dale',
#  'dan',
#  'daren',
#  'daren farmer',
#  'data',
#  'data cannot',
#  'data unknown',
#  'database',
#  'database alias',
#  'database unknown',
#  'dataerror',
#  'dataerror dbcaps',
#  'date',
#  'date 02',
#  'date 12',
#  'date of',
#  'dates',
#  'dave',
#  'david',
#  'davis',
#  'day',
#  'day to',
#  'days',
#  'dbcaps',
#  'dbcaps 97',
#  'de',
#  'de la',
#  'deadline',
#  'deal',
#  'deal is',
#  'deal with',
#  'dealer',
#  'dealers',
#  'dealings',
#  'deals',
#  'dear',
#  'death',
#  'debt',
#  'dec',
#  'december',
#  'decide',
#  'decided',
#  'decided to',
#  'deciding',
#  'deciding to',
#  'decision',
#  'decisions',
#  'decline',
#  'declined',
#  'declined to',
#  'default',
#  'degree',
#  'del',
#  'delay',
#  'delays',
#  'delete',
#  'deliver',
#  'delivered',
#  'deliveries',
#  'delivery',
#  'demand',
#  'department',
#  'deposit',
#  'deposited',
#  'der',
#  'deregulation',
#  'derivatives',
#  'des',
#  'described',
#  'description',
#  'design',
#  'designed',
#  'desire',
#  'desk',
#  'despite',
#  'detail',
#  'detailed',
#  'details',
#  'details of',
#  'detected',
#  'detected log',
#  'determine',
#  'develop',
#  'developed',
#  'developing',
#  'development',
#  'development enron',
#  'development of',
#  'dial',
#  'did',
#  'did not',
#  'didn',
#  'die',
#  'died',
#  'differ',
#  'differ materially',
#  'difference',
#  'different',
#  'difficult',
#  'digital',
#  'diligence',
#  'dinner',
#  'direct',
#  'direction',
#  'directly',
#  'directly to',
#  'director',
#  'director of',
#  'directors',
#  'directory',
#  'disclose',
#  'disclosed',
#  'disclosure',
#  'discount',
#  'discovered',
#  'discreet',
#  'discuss',
#  'discuss the',
#  'discussed',
#  'discussion',
#  'discussions',
#  'discussions with',
#  'distribute',
#  'distribution',
#  'division',
#  'do',
#  'do it',
#  'do not',
#  'do so',
#  'do that',
#  'do the',
#  'do this',
#  'do you',
#  'doc',
#  'doctor',
#  'document',
#  'documentation',
#  'documents',
#  'does',
#  'does not',
#  'doesn',
#  'doing',
#  'dollar',
#  'dollars',
#  'domain',
#  'domestic',
#  'don',
#  'don have',
#  'don know',
#  'don think',
#  'don want',
#  'done',
#  'donna',
#  'door',
#  'dose',
#  'double',
#  'doubt',
#  'dow',
#  'dow jones',
#  'dowjones',
#  'down',
#  'down the',
#  'downgrade',
#  'downgraded',
#  'download',
#  'dpc',
#  'dpr',
#  'dr',
#  'draft',
#  'draw',
#  'draw graphics',
#  'drawn',
#  'drew',
#  'drive',
#  'drop',
#  'dropped',
#  'drug',
#  'drugs',
#  'due',
#  'due diligence',
#  'due to',
#  'duke',
#  'during',
#  'during the',
#  'duty',
#  'duty free',
#  'dvd',
#  'dwr',
#  'dynegy',
#  'dynegy inc',
#  'ea',
#  'each',
#  'each of',
#  'earlier',
#  'earlier this',
#  'early',
#  'earn',
#  'earning',
#  'earnings',
#  'easier',
#  'easily',
#  'east',
#  'easy',
#  'easy to',
#  'eb',
#  'ebay',
#  'ebs',
#  'ec',
#  'economic',
#  'economy',
#  'ect',
#  'ect ect',
#  'ect ectcc',
#  'ect ectsubject',
#  'ect on',
#  'ectcc',
#  'ectcc subject',
#  'ectsubject',
#  'ectsubject re',
#  'ed',
#  'edge',
#  'edison',
#  'edition',
#  'edu',
#  'education',
#  'edward',
#  'ee',
#  'ees',
#  'ees ees',
#  'eff',
#  'effect',
#  'effective',
#  'effectively',
#  'effects',
#  'efficient',
#  'effort',
#  'effort to',
#  'efforts',
#  'egm',
#  'eight',
#  'either',
#  'el',
#  'el paso',
#  'electric',
#  'electricity',
#  'electronic',
#  'else',
#  'em',
#  'emai',
#  'email',
#  'email address',
#  'email addresses',
#  'email contains',
#  'email is',
#  'email to',
#  'emails',
#  'emerging',
#  'emerson',
#  'employee',
#  'employees',
#  'employment',
#  'en',
#  'ena',
#  'enable',
#  'encourage',
#  'end',
#  'end of',
#  'ended',
#  'ene',
#  'energy',
#  'energy and',
#  'energy company',
#  'energy markets',
#  'energy service',
#  'energy services',
#  'energy trader',
#  'energy trading',
#  'engineering',
#  'engines',
#  'english',
#  'english news',
#  'enhanced',
#  'enjoy',
#  'enough',
#  'enron',
#  'enron and',
#  'enron com',
#  'enron comcc',
#  'enron communications',
#  'enron corp',
#  'enron credit',
#  'enron development',
#  'enron enron',
#  'enron enroncc',
#  'enron enronsubject',
#  'enron enronxgate',
#  'enron had',
#  'enron has',
#  'enron in',
#  'enron is',
#  'enron north',
#  'enron on',
#  'enron said',
#  'enron shares',
#  'enron stock',
#  'enron the',
#  'enron to',
#  'enron was',
#  'enron will',
#  'enroncc',
#  'enroncc subject',
#  'enrononline',
#  'enronsubject',
#  'enronxgate',
#  'enronxgate on',
#  'ensure',
#  'ensure that',
#  'enter',
#  'entered',
#  'entered into',
#  'enterprise',
#  'entertainment',
#  'entire',
#  'entities',
#  'entity',
#  'entry',
#  'environment',
#  'environmental',
#  'enw',
#  'eogi',
#  'eol',
#  'epmi',
#  'equipment',
#  'equity',
#  'eric',
#  'error',
#  'errors',
#  'es',
#  'especially',
#  'est',
#  'establish',
#  'established',
#  'estate',
#  'estimate',
#  'estimated',
#  'estimates',
#  'estimates and',
#  'estimates believes',
#  'et',
#  'et enron',
#  'etc',
#  'ets',
#  'euro',
#  'europe',
#  'european',
#  'euros',
#  'evaluation',
#  'even',
#  'even if',
#  'evening',
#  'event',
#  'events',
#  'events to',
#  'ever',
#  'every',
#  'everyone',
#  'everything',
#  'ews',
#  'ex',
#  'exactly',
#  'example',
#  'examples',
#  'excel',
#  'excellent',
#  'except',
#  'excess',
#  'exchange',
#  'exchange act',
#  'exchange commission',
#  'exciting',
#  'exclusive',
#  'executed',
#  'executive',
#  'executives',
#  'exercise',
#  'existing',
#  'expand',
#  'expanding',
#  'expansion',
#  'expect',
#  'expectations',
#  'expectations beliefs',
#  'expectations estimates',
#  'expected',
#  'expected to',
#  'expects',
#  'expense',
#  'expenses',
#  'expensive',
#  'experience',
#  'experienced',
#  'expert',
#  'experts',
#  'expires',
#  'explain',
#  'exploration',
#  'exposure',
#  'exposure to',
#  'express',
#  'expressed',
#  'ext',
#  'extend',
#  'extended',
#  'extensive',
#  'external',
#  'extra',
#  'extremely',
#  'eye',
#  'face',
#  'facilities',
#  'facility',
#  'fact',
#  'fact and',
#  'fact that',
#  'factor',
#  'factors',
#  'facts',
#  'factual',
#  'failed',
#  'failure',
#  'fair',
#  'faith',
#  'fall',
#  'fallen',
#  'familiar',
#  'familiar with',
#  'family',
#  'far',
#  'farmer',
#  'farmer hou',
#  'fast',
#  'faster',
#  'fastow',
#  'fat',
#  'father',
#  'fax',
#  'fear',
#  'featured',
#  'featured company',
#  'featured within',
#  'features',
#  'feb',
#  'february',
#  'federal',
#  'fee',
#  'feedback',
#  'feel',
#  'feel free',
#  'feel you',
#  'fees',
#  'feet',
#  'fell',
#  'felt',
#  'ferc',
#  'few',
#  'few days',
#  'few weeks',
#  'field',
#  'figure',
#  'file',
#  'file for',
#  'file portland',
#  'filed',
#  'files',
#  'filing',
#  'filings',
#  'fill',
#  'fill out',
#  'final',
#  'final schedules',
#  'finally',
#  'finance',
#  'financial',
#  'financial officer',
#  'financial times',
#  'financing',
#  'find',
#  'find out',
#  'find the',
#  'finding',
#  'fine',
#  'fire',
#  'fired',
#  'firm',
#  'firms',
#  'first',
#  'fit',
#  'fitch',
#  'five',
#  'five hundred',
#  'fixed',
#  'fl',
#  'flash',
#  'floor',
#  'flow',
#  'focus',
#  'focus on',
#  'focused',
#  'focused on',
#  'follow',
#  'follow this',
#  'follow up',
#  'followed',
#  'following',
#  'follows',
#  'font',
#  'font size',
#  'food',
#  'for',
#  'for all',
#  'for an',
#  'for any',
#  'for as',
#  'for being',
#  'for both',
#  'for commercial',
#  'for each',
#  'for enron',
#  'for example',
#  'for free',
#  'for further',
#  'for gas',
#  'for information',
#  'for it',
#  'for its',
#  'for me',
#  'for more',
#  'for new',
#  'for our',
#  'for some',
#  'for that',
#  'for the',
#  'for their',
#  'for these',
#  'for this',
#  'for us',
#  'for you',
#  'for your',
#  'force',
#  'forced',
#  'forecast',
#  'foreign',
#  'foresee',
#  'foresee expects',
#  'form',
#  'formal',
#  'format',
#  'former',
#  'former chief',
#  'forms',
#  'formula',
#  'forth',
#  'forthe',
#  'fortune',
#  'forward',
#  'forward looking',
#  'forward ooking',
#  'forward to',
#  'forwarded',
#  'forwarded by',
#  'found',
#  'four',
#  'fourth',
#  'frank',
#  'fred',
#  'free',
#  'free to',
#  'fresh',
#  'fri',
#  'friday',
#  'friend',
#  'friends',
#  'from',
#  'from all',
#  'from enron',
#  'from its',
#  'from kitchen',
#  'from my',
#  'from our',
#  'from registered',
#  'from such',
#  'from the',
#  'from third',
#  'from this',
#  'from those',
#  'from us',
#  'from vince',
#  'from you',
#  'from your',
#  'front',
#  'ft',
#  'fuel',
#  'full',
#  'fully',
#  'fun',
#  'function',
#  'functions',
#  'fund',
#  'funding',
#  'funds',
#  'further',
#  'furthermore',
#  'future',
#  'future events',
#  'future looking',
#  'future mailings',
#  'futures',
#  'fw',
#  'fwd',
#  'fyi',
#  'gain',
#  'gains',
#  'game',
#  'games',
#  'gary',
#  'gas',
#  'gas and',
#  'gas daily',
#  'gas pipeline',
#  'gas prices',
#  'gathered',
#  'gathering',
#  'gave',
#  'ge',
#  'geec',
#  'general',
#  'generate',
#  'generated',
#  'generating',
#  'generation',
#  'generators',
#  'generic',
#  'george',
#  'get',
#  'get back',
#  'get in',
#  'get it',
#  'get the',
#  'get this',
#  'get your',
#  'gets',
#  'getting',
#  'giant',
#  'gibner',
#  'gibner hou',
#  'gift',
#  'girl',
#  'girls',
#  'give',
#  'give me',
#  'give you',
#  'given',
#  'given the',
#  'gives',
#  'giving',
#  'glad',
#  'glad to',
#  'global',
#  'go',
#  'go here',
#  'go to',
#  'goal',
#  'goals',
#  'god',
#  'goes',
#  'going',
#  'going to',
#  'gold',
#  'goldman',
#  'gone',
#  'good',
#  'got',
#  'gotten',
#  'gov',
#  'government',
#  'governor',
#  'grade',
#  'graduate',
#  'grant',
#  'grants',
#  'graphics',
#  'graphics suite',
#  'graves',
#  'great',
#  'greater',
#  'green',
#  'greg',
#  'grid',
#  'ground',
#  'group',
#  'group and',
#  'groups',
#  'grow',
#  'growing',
#  'growth',
#  'guarantee',
#  'guaranteed',
#  'guide',
#  'guy',
#  'guys',
#  'had',
#  'had been',
#  'had to',
#  'half',
#  'half of',
#  'hall',
#  'hand',
#  'handle',
#  'handling',
#  'hands',
#  'happen',
#  'happening',
#  'happy',
#  'happy to',
#  'hard',
#  'hard to',
#  'harris',
#  'has',
#  'has already',
#  'has been',
#  'has come',
#  'has not',
#  'has the',
#  'have',
#  'have all',
#  'have an',
#  'have any',
#  'have been',
#  'have had',
#  'have in',
#  'have made',
#  'have no',
#  'have not',
#  'have received',
#  'have some',
#  'have the',
#  'have to',
#  'have you',
#  'haven',
#  'having',
#  'he',
#  'he had',
#  'he has',
#  'he is',
#  'he said',
#  'he was',
#  'he will',
#  'he would',
#  'head',
#  'head of',
#  'headed',
#  'health',
#  'hear',
#  'heard',
#  'hearing',
#  'hearing from',
#  'heart',
#  'heavy',
#  'hedge',
#  'hedging',
#  'height',
#  'held',
#  'held on',
#  'hello',
#  'help',
#  'help you',
#  'helped',
#  'helping',
#  'helps',
#  'hence',
#  'her',
#  'here',
#  'here are',
#  'here for',
#  'here http',
#  'here in',
#  'here is',
#  'here or',
#  'here to',
#  'herein',
#  'herein as',
#  'hesitate',
#  'hi',
#  'high',
#  'high quality',
#  'higher',
#  'highest',
#  'highly',
#  'hill',
#  'him',
#  'him to',
#  'his',
#  'historical',
#  'historical fact',
#  'history',
#  'hit',
#  'hold',
#  'holding',
#  'holdings',
#  'holds',
#  'holiday',
#  'holidays',
#  'home',
#  'homes',
#  'hope',
#  'hope that',
#  'hope to',
#  'hope you',
#  'host',
#  'hot',
#  'hotel',
#  'hotmail',
#  'hou',
#  'hou ect',
#  'hou ees',
#  'hour',
#  'hourahead',
#  'hourahead hour',
#  'hours',
#  'house',
#  'houston',
#  'houston based',
#  'how',
#  'how much',
#  'how the',
#  'how to',
#  'howard',
#  'however',
#  'however the',
#  'hpl',
#  'hplc',
#  'hr',
#  'href',
#  'href http',
#  'html',
#  'http',
#  'http 69',
#  'http www',
#  'huge',
#  'human',
#  'hundred',
#  'hundred thousand',
#  'hundreds',
#  'hundreds of',
#  'husband',
#  'id',
#  'idea',
#  'ideas',
#  'identified',
#  'identified through',
#  'identify',
#  'identity',
#  'ie',
#  'if',
#  'if any',
#  'if enron',
#  'if it',
#  'if the',
#  'if there',
#  'if they',
#  'if this',
#  'if we',
#  'if you',
#  'ii',
#  'iii',
#  'im',
#  'image',
#  'imagine',
#  'immediate',
#  'immediately',
#  'impact',
#  'impact on',
#  'implementation',
#  'importance',
#  'important',
#  'important to',
#  'improve',
#  'improved',
#  'improvement',
#  'in',
#  'in addition',
#  'in advance',
#  'in all',
#  'in an',
#  'in any',
#  'in california',
#  'in case',
#  'in cash',
#  'in compliance',
#  'in enron',
#  'in error',
#  'in europe',
#  'in fact',
#  'in his',
#  'in houston',
#  'in it',
#  'in its',
#  'in london',
#  'in mind',
#  'in my',
#  'in new',
#  'in next',
#  'in one',
#  'in or',
#  'in order',
#  'in our',
#  'in place',
#  'in recent',
#  'in stock',
#  'in stocks',
#  'in that',
#  'in the',
#  'in their',
#  'in these',
#  'in this',
#  'in to',
#  'in which',
#  'in your',
#  'inc',
#  'inc all',
#  'inc is',
#  'inciude',
#  'inciuding',
#  'include',
#  'include the',
#  'included',
#  'included in',
#  'includes',
#  'including',
#  'including the',
#  'income',
#  'increase',
#  'increased',
#  'increases',
#  'increasing',
#  'independent',
#  'index',
#  'india',
#  'indian',
#  'indicate',
#  'indicated',
#  'indicating',
#  'indicating certain',
#  'indicative',
#  'indicative of',
#  'individual',
#  'individuals',
#  'industrial',
#  'industries',
#  'industry',
#  'info',
#  'inform',
#  'inform you',
#  'information',
#  'information about',
#  'information and',
#  'information contained',
#  'information herein',
#  'information in',
#  'information is',
#  'information on',
#  'information provided',
#  'information to',
#  'information within',
#  'informed',
#  'infrastructure',
#  'inherent',
#  'inherent conflict',
#  'initial',
#  'innovative',
#  'input',
#  'inquiry',
#  'inside',
#  'instant',
#  'instant download',
#  'instead',
#  'instead of',
#  'institutions',
#  'instructions',
#  'insurance',
#  'integration',
#  'intend',
#  'intended',
#  'intended for',
#  'intended recipient',
#  'intent',
#  'interest',
#  'interest in',
#  'interest resulting',
#  'interested',
#  'interested in',
#  'interesting',
#  'interests',
#  'interface',
#  'internal',
#  'internationa',
#  'international',
#  'internet',
#  'interview',
#  'interview with',
#  'interviews',
#  'inthe',
#  'into',
#  'into the',
#  'into your',
#  'introduce',
#  'invest',
#  'invested',
#  'investigation',
#  'investing',
#  'investing in',
#  'investing stocks',
#  'investment',
#  'investment advice',
#  'investment advisor',
#  'investment grade',
#  'investments',
#  'investor',
#  'investor confidence',
#  'investors',
#  'investors service',
#  'invitation',
#  'invitation to',
#  'invite',
#  'invoice',
#  'involve',
#  'involve number',
#  'involved',
#  'involved in',
#  'involving',
#  'ion',
#  'iris',
#  'is',
#  'is also',
#  'is an',
#  'is available',
#  'is being',
#  'is currently',
#  'is expected',
#  'is for',
#  'is going',
#  'is in',
#  'is intended',
#  'is it',
#  'is just',
#  'is my',
#  'is no',
#  'is not',
#  'is now',
#  'is on',
#  'is one',
#  'is only',
#  'is our',
#  'is paid',
#  'is part',
#  'is required',
#  'is still',
#  'is that',
#  'is the',
#  'is this',
#  'is to',
#  'is very',
#  'is what',
#  'is your',
#  'isn',
#  'iso',
#  'iso 8859',
#  'iso final',
#  'issue',
#  'issued',
#  'issues',
#  'it',
#  'it also',
#  'it and',
#  'it can',
#  'it could',
#  'it for',
#  'it had',
#  'it has',
#  'it in',
#  'it is',
#  'it may',
#  'it on',
#  'it out',
#  'it right',
#  'it the',
#  'it to',
#  'it was',
#  'it will',
#  'it with',
#  'it would',
#  'item',
#  'items',
#  'its',
#  'its accuracy',
#  'its stock',
#  'itself',
#  'iv',
#  'jackie',
#  'james',
#  'jan',
#  'janet',
#  'january',
#  'japan',
#  'jay',
#  'jean',
#  'jeff',
#  'jeffrey',
#  'jennifer',
#  'jim',
#  'job',
#  'jobs',
#  'joe',
#  'john',
#  'johnson',
#  'join',
#  'join us',
#  'joining',
#  'joint',
#  'jones',
#  'jones company',
#  'joseph',
#  'journal',
#  'jr',
#  'juan',
#  'judge',
#  'jul',
#  'jul 2005',
#  'julie',
#  'july',
#  'jump',
#  'june',
#  'junk',
#  'just',
#  'just to',
#  'kaminski',
#  'kaminski enron',
#  'kaminski hou',
#  'karen',
#  'keep',
#  'keeping',
#  'ken',
#  'ken lay',
#  'kenneth',
#  'kenneth lay',
#  'kept',
#  'kernel',
#  'kevin',
#  'key',
#  'kim',
#  'kimberly',
#  'kin',
#  'kind',
#  'kind of',
#  'kitchen',
#  'kitchen louisesent',
#  'knew',
#  'know',
#  'know about',
#  'know how',
#  'know if',
#  'know that',
#  'know the',
#  'know what',
#  'knowledge',
#  'known',
#  'known as',
#  'knows',
#  'la',
#  'lack',
#  'lack of',
#  'lake',
#  'land',
#  'language',
#  'large',
#  'larger',
#  'largest',
#  'las',
#  'last',
#  'last month',
#  'last week',
#  'last year',
#  'late',
#  'later',
#  'later than',
#  'latest',
#  'launch',
#  'laura',
#  'lauraan',
#  'lavorato',
#  'law',
#  'lawsuit',
#  'lawsuits',
#  'lay',
#  'lay said',
#  'ld',
#  'le',
#  'lead',
#  'leader',
#  'leadership',
#  'leading',
#  'learn',
#  'least',
#  'leave',
#  'leaving',
#  'led',
#  'lee',
#  'left',
#  'legal',
#  'legislation',
#  'lenders',
#  'leslie',
#  'less',
#  'less than',
#  'let',
#  'let me',
#  'let us',
#  'let you',
#  'letter',
#  'level',
#  'levels',
#  'liability',
#  'license',
#  'licensed',
#  'life',
#  'light',
#  'like',
#  'like the',
#  'like to',
#  'like you',
#  'likely',
#  'likely to',
#  'limit',
#  'limited',
#  'limited 2001',
#  'limited to',
#  'line',
#  'line of',
#  'lines',
#  'link',
#  'link below',
#  'link to',
#  'links',
#  'linux',
#  'liquidity',
#  'lisa',
#  'list',
#  'list of',
#  'list please',
#  'listed',
#  'listing',
#  'lists',
#  'litigation',
#  'little',
#  'live',
#  'living',
#  'ljm',
#  'll',
#  'll be',
#  'llc',
#  'lloyd',
#  'lng',
#  'lo',
#  'load',
#  'loan',
#  'loans',
#  'local',
#  'locate',
#  'located',
#  'location',
#  'locations',
#  'log',
#  'log messages',
#  'logistics',
#  'logo',
#  'logos',
#  'lokay',
#  'lon',
#  'lon ect',
#  'london',
#  'long',
#  'long as',
#  'long term',
#  'longer',
#  'look',
#  'look at',
#  'look forward',
#  'looked',
#  'looking',
#  'looking for',
#  'looking forward',
#  'looking statements',
#  'looks',
#  'los',
#  'lose',
#  'loss',
#  'loss of',
#  'losses',
#  'lost',
#  'lot',
#  'lot of',
#  'lots',
#  'lottery',
#  'louise',
#  'louise kitchen',
#  'louisesent',
#  'love',
#  'low',
#  'low as',
#  'lower',
#  'lowered',
#  'lowest',
#  'lp',
#  'lst',
#  'ltd',
#  'lu',
#  'luck',
#  'lucky',
#  'lunch',
#  'machine',
#  'macromedia',
#  'made',
#  'made that',
#  'magazine',
#  'maharashtra',
#  'mai',
#  'mail',
#  'mail address',
#  'mail to',
#  'mailing',
#  'mailing list',
#  'mailings',
#  'mails',
#  'mailto',
#  'main',
#  'maintain',
#  'maintenance',
#  'major',
#  'majordomo',
#  'make',
#  'make it',
#  'make sure',
#  'make the',
#  'make you',
#  'maker',
#  'makes',
#  'making',
#  'male',
#  'man',
#  'manage',
#  'managed',
#  'management',
#  'management and',
#  'management team',
#  'manager',
#  'managers',
#  'managing',
#  'managing director',
#  'manner',
#  'manual',
#  'manufacturing',
#  'many',
#  'many more',
#  'many of',
#  'mar',
#  'march',
#  'margin',
#  'mark',
#  'market',
#  'market and',
#  'market in',
#  'marketing',
#  'markets',
#  'markets and',
#  'martin',
#  'mary',
#  'massive',
#  'master',
#  'match',
#  'materia',
#  'material',
#  'material within',
#  'materially',
#  'materially from',
#  'materials',
#  'matt',
#  'matter',
#  'matters',
#  'maureen',
#  'max',
#  'maximum',
#  'may',
#  'may be',
#  'may could',
#  'may have',
#  'may not',
#  'maybe',
#  'mb',
#  'mba',
#  'mcmahon',
#  'me',
#  'me and',
#  'me at',
#  'me if',
#  'me in',
#  'me know',
#  'me on',
#  'me that',
#  'me the',
#  'me to',
#  'me with',
#  'mean',
#  'meaning',
#  'meaning of',
#  'means',
#  'meant',
#  'measure',
#  'media',
#  'medical',
#  'medication',
#  'medications',
#  'meds',
#  'meet',
#  'meet with',
#  'meeting',
#  'meeting with',
#  'meetings',
#  'megan',
#  'melissa',
#  'member',
#  'member of',
#  'members',
#  'members of',
#  'membership',
#  'memo',
#  'men',
#  'mentioned',
#  'merchant',
#  'merger',
#  'message',
#  'message from',
#  'message is',
#  'message to',
#  'messages',
#  'messages parsing',
#  'met',
#  'metals',
#  'meter',
#  'method',
#  'mexico',
#  'meyers',
#  'mg',
#  'mi',
#  'michael',
#  'michelle',
#  'microsoft',
#  'microsoft office',
#  'mid',
#  'middle',
#  'might',
#  'might be',
#  'might have',
#  'might occur',
#  'mike',
#  'miles',
#  'military',
#  'miller',
#  'million',
#  'million in',
#  'million shares',
#  'millions',
#  'millions of',
#  'min',
#  'mind',
#  'minimum',
#  'mining',
#  'minister',
#  'minute',
#  'minutes',
#  'miss',
#  'mission',
#  'mix',
#  'mm',
#  'mmbtu',
#  'mmcf',
#  'mo',
#  'mobile',
#  'model',
#  'modeling',
#  'models',
#  'moment',
#  'mon',
#  'monday',
#  'money',
#  'money back',
#  'money by',
#  'money in',
#  'money to',
#  'monitor',
#  'month',
#  'month of',
#  'monthly',
#  'months',
#  'moody',
#  'moody investors',
#  'moore',
#  'more',
#  'more about',
#  'more details',
#  'more information',
#  'more than',
#  'morgan',
#  'morgan chase',
#  'morning',
#  'mortgage',
#  'most',
#  'most of',
#  'most recent',
#  'mother',
#  'move',
#  'moved',
#  'movies',
#  'moving',
#  'mr',
#  'mr fastow',
#  'mr lay',
#  'mrs',
#  'ms',
#  'mseb',
#  'msn',
#  'much',
#  'much as',
#  'much for',
#  'much more',
#  'much of',
#  'multi',
#  'multiple',
#  'music',
#  'must',
#  'must be',
#  'mutual',
#  'mw',
#  'mx',
#  'mx 2004',
#  'my',
#  'my family',
#  'my father',
#  'my name',
#  'myself',
#  'na',
#  'na enron',
#  'name',
#  'name and',
#  'name is',
#  'named',
#  'names',
#  'nasdaq',
#  'nat',
#  'nation',
#  'national',
#  'natural',
#  'natural gas',
#  'nature',
#  'nbsp',
#  'nbsp nbsp',
#  'nd',
#  'ne',
#  'near',
#  'nearly',
#  'necessary',
#  'necessary to',
#  'need',
#  'need for',
#  'need to',
#  'needed',
#  'needed to',
#  'needs',
#  'needs to',
#  'negative',
#  'negotiated',
#  'negotiations',
#  'neither',
#  'net',
#  'netco',
#  'netscape',
#  'network',
#  'networks',
#  'never',
#  'new',
#  'new york',
#  'news',
#  'news release',
#  'news service',
#  'newsietter',
#  'newsletter',
#  'newsletter is',
#  'next',
#  'next day',
#  'next of',
#  'next week',
#  'next year',
#  'nice',
#  'nice day',
#  'nigeria',
#  'night',
#  'nine',
#  'no',
#  'no ancillary',
#  'no assurance',
#  'no longer',
#  'no more',
#  'no one',
#  'no thanks',
#  'no variances',
#  'nom',
#  'nom for',
#  'nomination',
#  'noms',
#  'non',
#  'none',
#  'none of',
#  'nor',
#  'normal',
#  'normally',
#  'north',
#  'north america',
#  'north american',
#  'northern',
#  'northwest',
#  'norton',
#  'not',
#  'not an',
#  'not be',
#  'not been',
#  'not have',
#  'not in',
#  'not interested',
#  'not investment',
#  'not omit',
#  'not only',
#  'not registered',
#  'not reply',
#  'not represent',
#  'not statements',
#  'not sure',
#  'not the',
#  'not to',
#  'not want',
#  'not wish',
#  'note',
#  'note that',
#  'noted',
#  'notes',
#  'nothing',
#  'notice',
#  'notification',
#  'notify',
#  'nov',
#  'november',
#  'now',
#  'now and',
#  'number',
#  'number is',
#  'number of',
#  'numbers',
#  'numbers and',
#  'numerous',
#  'ny',
#  'nymex',
#  'nyse',
#  'objectives',
#  'obligation',
#  'obligations',
#  'obtain',
#  'obviously',
#  'occur',
#  'oct',
#  'october',
#  'oem',
#  'of',
#  'of 1933',
#  'of 1934',
#  'of 1995',
#  'of all',
#  'of an',
#  'of any',
#  'of bankruptcy',
#  'of business',
#  'of companies',
#  'of company',
#  'of course',
#  'of credit',
#  'of dollars',
#  'of energy',
#  'of enron',
#  'of future',
#  'of gas',
#  'of his',
#  'of historical',
#  'of interest',
#  'of investment',
#  'of it',
#  'of its',
#  'of kin',
#  'of money',
#  'of my',
#  'of natural',
#  'of new',
#  'of other',
#  'of our',
#  'of people',
#  'of power',
#  'of risks',
#  'of section',
#  'of some',
#  'of texas',
#  'of that',
#  'of the',
#  'of their',
#  'of them',
#  'of these',
#  'of this',
#  'of those',
#  'of time',
#  'of us',
#  'of what',
#  'of which',
#  'of words',
#  'of you',
#  'of your',
#  'off',
#  'off balance',
#  'off the',
#  'offer',
#  'offer to',
#  'offered',
#  'offering',
#  'offers',
#  'office',
#  'office of',
#  'office xp',
#  'officer',
#  'officer andrew',
#  'officer director',
#  'officers',
#  'offices',
#  'official',
#  'officials',
#  'often',
#  'ofthe',
#  'oi',
#  'oi and',
#  'oil',
#  'oil and',
#  'oil gas',
#  'ok',
#  'old',
#  'omit',
#  'on',
#  'on 01',
#  'on 02',
#  'on 03',
#  'on 04',
#  'on 05',
#  'on 06',
#  'on 08',
#  'on 09',
#  'on 10',
#  'on 11',
#  'on 12',
#  'on all',
#  'on an',
#  'on behalf',
#  'on closed',
#  'on enron',
#  'on expectations',
#  'on friday',
#  'on how',
#  'on it',
#  'on its',
#  'on line',
#  'on monday',
#  'on my',
#  'on our',
#  'on the',
#  'on their',
#  'on this',
#  'on thursday',
#  'on to',
#  'on tuesday',
#  'on wednesday',
#  'on your',
#  'once',
#  'once again',
#  'once the',
#  'one',
#  'one of',
#  'one or',
#  'one trade',
#  'ones',
#  'ongoing',
#  'oniy',
#  'online',
#  'only',
#  'only and',
#  'only if',
#  'onthe',
#  'onto',
#  'oo',
#  'ooking',
#  'ooking statements',
#  'ooo',
#  'op',
#  'open',
#  'opening',
#  'operate',
#  'operating',
#  'operation',
#  'operation on',
#  'operational',
#  'operations',
#  'opinion',
#  'opinions',
#  'opportunities',
#  'opportunity',
#  'opportunity to',
#  'opt',
#  'option',
#  'options',
#  'or',
#  'or an',
#  'or any',
#  'or copy',
#  'or events',
#  'or future',
#  'or if',
#  'or might',
#  'or more',
#  'or not',
#  'or performance',
#  'or sell',
#  'or send',
#  'or solicitation',
#  'or that',
#  'or the',
#  'or to',
#  'or your',
#  'order',
#  'order for',
#  'order to',
#  'ordered',
#  'ordering',
#  'orders',
#  'org',
#  'organization',
#  'organizations',
#  'original',
#  'original message',
#  'origination',
#  'otc',
#  'other',
#  'other factors',
#  'others',
#  'otherwise',
#  'our',
#  'our membership',
#  'our price',
#  'our site',
#  'our website',
#  'out',
#  'out for',
#  'out how',
#  'out of',
#  'out the',
#  'out this',
#  'out to',
#  'outlook',
#  'outside',
#  'outstanding',
#  'over',
#  'over the',
#  'overall',
#  'overnight',
#  'overview',
#  'own',
#  'owned',
#  'owner',
#  'ownership',
#  'owns',
#  'oxley',
#  'pa',
#  'pack',
#  'package',
#  'packages',
#  'page',
#  'pages',
#  'paid',
#  'pain',
#  'paliourg',
#  'palmer',
#  'panel',
#  'paper',
#  'para',
#  'paragraph',
#  'park',
#  'parsing',
#  'parsing file',
#  'part',
#  'part of',
#  'participants',
#  'participate',
#  'participate in',
#  'participation',
#  'particular',
#  'particularly',
#  'parties',
#  'partner',
#  'partners',
#  'partnership',
#  'partnerships',
#  'party',
#  'paso',
#  'pass',
#  'passed',
#  'password',
#  'past',
#  'past performance',
#  'paste',
#  'pat',
#  'path',
#  'patrick',
#  'paul',
#  'pay',
#  'paying',
#  'payment',
#  'payments',
#  'paypal',
#  'pc',
#  'pdf',
#  'peak',
#  'pec',
#  'pec pec',
#  'pending',
#  'penis',
#  'penny',
#  'people',
#  'people who',
#  'pep',
#  'per',
#  'per cent',
#  'per day',
#  'per share',
#  'percent',
#  'percent of',
#  'percent to',
#  'percentage',
#  'perfect',
#  'perform',
#  'perform this',
#  'performance',
#  'performance are',
#  'performance is',
#  'performance of',
#  'perhaps',
#  'period',
#  'permanent',
#  'person',
#  'personal',
#  'personnel',
#  'perspective',
#  'pertaining',
#  'pertaining to',
#  'peter',
#  'petroleum',
#  'pg',
#  'pge',
#  'ph',
#  'pharmacy',
#  'phase',
#  'phone',
#  'photoshop',
#  'photoshop cs',
#  'php',
#  'physical',
#  'pians',
#  'pick',
#  'picture',
#  'piease',
#  'pill',
#  'pills',
#  'pinnacle',
#  'pipe',
#  'pipeline',
#  'pipelines',
#  'pjm',
#  'place',
#  'placed',
#  'placed in',
#  'plan',
#  'plan to',
#  'planned',
#  'planning',
#  'plans',
#  'plans projections',
#  'plans to',
#  'plant',
#  'plants',
#  'platform',
#  'play',
#  'player',
#  'players',
#  'please',
#  'please advise',
#  'please be',
#  'please call',
#  'please click',
#  'please contact',
#  'please do',
#  'please feel',
#  'please find',
#  'please give',
#  'please go',
#  'please let',
#  'please note',
#  'please reply',
#  'please see',
#  'please send',
#  'pleased',
#  'pleased to',
#  'pleasure',
#  'plunged',
#  'plus',
#  'pm',
#  'pm to',
#  'pmto',
#  'pmto vince',
#  'point',
#  'points',
#  'poised',
#  'policies',
#  'policy',
#  'political',
#  'poor',
#  'pop',
#  'popular',
#  'por',
#  'port',
#  'portfolio',
#  'portion',
#  'portland',
#  'portland westdesk',
#  'position',
#  'position in',
#  'positioned',
#  'positioned to',
#  'positions',
#  'positive',
#  'possibility',
#  'possible',
#  'possibly',
#  'post',
#  'posted',
#  'posting',
#  'potentia',
#  'potential',
#  'pounds',
#  'power',
#  'power and',
#  'power plant',
#  'power plants',
#  'powerful',
#  'pr',
#  'practices',
#  'prc',
#  'pre',
#  'predictions',
#  'prefer',
#  'preferred',
#  'preliminary',
#  'premier',
#  'premiere',
#  'premium',
#  'preparation',
#  'prepare',
#  'prepared',
#  'prescription',
#  'presence',
#  'present',
#  'presentation',
#  'presentations',
#  'presented',
#  'presently',
#  'president',
#  'president and',
#  'president of',
#  'press',
#  'press release',
#  'press releases',
#  'pressure',
#  'presto',
#  'pretty',
#  'previous',
#  'previously',
#  'price',
#  'price in',
#  'price of',
#  'priced',
#  'prices',
#  'prices and',
#  'prices in',
#  'pricing',
#  'primarily',
#  'primary',
#  'print',
#  'prior',
#  'prior to',
#  'priority',
#  'privacy',
#  'private',
#  'privileged',
#  'prize',
#  'pro',
#  'probably',
#  'problem',
#  'problems',
#  'procedures',
#  'proceed',
#  'process',
#  'process of',
#  'processed',
#  'processes',
#  'processing',
#  'produce',
#  'produced',
#  'producer',
#  'producers',
#  'producing',
#  'product',
#  'production',
#  'products',
#  'products and',
#  'professional',
#  'professionals',
#  'professor',
#  'profile',
#  'profiled',
#  'profit',
#  'profitable',
#  'profits',
#  'program',
#  'programs',
#  'progress',
#  'prohibited',
#  'project',
#  'projecthoneypot',
#  'projections',
#  'projections at',
#  'projections objectives',
#  'projects',
#  'projects foresee',
#  'promise',
#  'promotion',
#  'promotional',
#  'promotions',
#  'prompt',
#  'proper',
#  'properties',
#  'property',
#  'property of',
#  'proposal',
#  'proposed',
#  'proprietary',
#  'prospects',
#  'protect',
#  'protection',
#  'protocol',
#  'proved',
#  'proven',
#  'provide',
#  'provided',
#  'provided and',
#  'provided within',
#  'provider',
#  'providers',
#  'provides',
#  'providing',
#  'pt',
#  'pubiisher',
#  'pubiisher of',
#  'public',
#  'publication',
#  'published',
#  'publisher',
#  'publisher of',
#  'pull',
#  'purchase',
#  'purchase of',
#  'purchased',
#  'purchases',
#  'purchasing',
#  'purpose',
#  'purposes',
#  'push',
#  'put',
#  'putting',
#  'qualified',
#  'qualify',
#  'quality',
#  'quarter',
#  'quarter of',
#  'quarterly',
#  'que',
#  'question',
#  'questions',
#  'questions about',
#  'questions or',
#  'questions please',
#  'quick',
#  'quick and',
#  'quickly',
#  'quite',
#  'quote',
#  'rac',
#  'raise',
#  'raised',
#  'ran',
#  'range',
#  'range of',
#  'rate',
#  'rates',
#  'rather',
#  'rather than',
#  'rating',
#  'ratings',
#  'ratio',
#  'raymond',
#  'rd',
#  're',
#  'reach',
#  'reached',
#  'read',
#  'read the',
#  'readers',
#  'readers and',
#  'reading',
#  'ready',
#  'ready to',
#  'real',
#  'real time',
#  'really',
#  'reason',
#  'reasons',
#  'rebecca',
#  'receipt',
#  'receipt of',
#  'receive',
#  'receive our',
#  'receive this',
#  'received',
#  'received this',
#  'receiving',
#  'receiving this',
#  'recent',
#  'recently',
#  'recipient',
#  'recommend',
#  'recommendation',
#  'recommended',
#  'record',
#  'records',
#  'recovery',
#  'recruiting',
#  'red',
#  'redmond',
#  'reduce',
#  'reduced',
#  'reduction',
#  'ref',
#  'reference',
#  'reference to',
#  'referenced',
#  'reflect',
#  'reform',
#  'reform act',
#  'regard',
#  'regarding',
#  'regarding the',
#  'regards',
#  'region',
#  'regional',
#  'register',
#  'registered',
#  'registered investment',
#  'registered professional',
#  'registration',
#  'regular',
#  'regulators',
#  'regulatory',
#  'related',
#  'related to',
#  'relations',
#  'relationship',
#  'release',
#  'released',
#  'releases',
#  'relevant',
#  'reliable',
#  'reliance',
#  'reliance on',
#  'reliant',
#  'relief',
#  'remain',
#  'remaining',
#  'remains',
#  'remember',
#  'remote',
#  'removal',
#  'remove',
#  'remove in',
#  'removed',
#  'removed from',
#  'reply',
#  'reply to',
#  'report',
#  'report be',
#  'report is',
#  'report to',
#  'report was',
#  'reported',
#  'reporting',
#  'reports',
#  'represent',
#  'representative',
#  'request',
#  'request for',
#  'requested',
#  'requests',
#  'require',
#  'required',
#  'required to',
#  'requirements',
#  'requires',
#  'research',
#  'research group',
#  'reserve',
#  'reserved',
#  'reserved enron',
#  'reserves',
#  'resolve',
#  'resource',
#  'resources',
#  'respect',
#  'respect to',
#  'respective',
#  'respond',
#  'respond to',
#  'response',
#  'response to',
#  'responsibilities',
#  'responsibility',
#  'responsible',
#  'responsible for',
#  'rest',
#  'rest of',
#  'resuits',
#  'result',
#  'result in',
#  'result of',
#  'resulting',
#  'resulting from',
#  'results',
#  'results or',
#  'resume',
#  'retail',
#  'return',
#  'returned',
#  'returns',
#  'reuters',
#  'reuters english',
#  'reuters limited',
#  'revenue',
#  'revenues',
#  'review',
#  'review and',
#  'review of',
#  'review the',
#  'reviewed',
#  'reviewing',
#  'reviews',
#  'revised',
#  'rice',
#  'rice edu',
#  'rich',
#  'richard',
#  'rick',
#  'right',
#  'right now',
#  'right to',
#  'rights',
#  'rights reserved',
#  'rise',
#  'risk',
#  'risk management',
#  'risks',
#  'risks and',
#  'rival',
#  'river',
#  'rm',
#  'road',
#  'rob',
#  'robert',
#  'robert cotten',
#  'robert lloyd',
#  'roberts',
#  'rock',
#  'role',
#  'rolex',
#  'roll',
#  'rom',
#  'room',
#  'rose',
#  'round',
#  'rs',
#  'rto',
#  'rules',
#  'run',
#  'run by',
#  'running',
#  'rx',
#  'sa',
#  'safe',
#  'safety',
#  'said',
#  'said enron',
#  'said he',
#  'said in',
#  'said it',
#  'said that',
#  'said the',
#  'said they',
#  'sale',
#  'sale of',
#  'sales',
#  'sally',
#  'sally beck',
#  'same',
#  'san',
#  'sap',
#  'sat',
#  'satisfaction',
#  'saturday',
#  'save',
#  'save your',
#  'saving',
#  'savings',
#  'saw',
#  'say',
#  'saying',
#  'says',
#  'schedule',
#  'scheduled',
#  'schedules',
#  'schedules awarded',
#  'scheduling',
#  'scheduling iso',
#  'school',
#  'school of',
#  'science',
#  'scott',
#  'screen',
#  'se',
#  'search',
#  'search engines',
#  'search for',
#  'season',
#  'sec',
#  'sec filings',
#  'second',
#  'secret',
#  'section',
#  'section 17',
#  'section 21',
#  'section 27',
#  'sector',
#  'secure',
#  'secured',
#  'securities',
#  'securities act',
#  'securities and',
#  'securities exchange',
#  'securities must',
#  'securities representative',
#  'security',
#  'security company',
#  'see',
#  'see attached',
#  'see if',
#  'see the',
#  'see you',
#  'seeing',
#  'seek',
#  'seek advice',
#  'seeking',
#  'seem',
#  'seems',
#  'seen',
#  'select',
#  'selected',
#  'selection',
#  'self',
#  'sell',
#  'sell any',
#  'selling',
#  'seminar',
#  'senate',
#  'send',
#  'send me',
#  'send you',
#  'sender',
#  'sending',
#  'senior',
#  'sense',
#  'sent',
#  'sent from',
#  'sent to',
#  'sent you',
#  'separate',
#  'sept',
#  'september',
#  'serial',
#  'serial number',
#  'series',
#  'serious',
#  'serve',
#  'served',
#  'server',
#  'service',
#  'service 11',
#  'service reuters',
#  'services',
#  'session',
#  'set',
#  'set up',
#  'setting',
#  'settlement',
#  'settlements',
#  'seven',
#  'several',
#  'sex',
#  'sexual',
#  'shall',
#  'shall be',
#  'share',
#  'share price',
#  'shared',
#  'shareholder',
#  'shareholder equity',
#  'shareholders',
#  'shares',
#  'shares of',
#  'she',
#  'she is',
#  'she said',
#  'sheet',
#  'sheets',
#  'sheila',
#  'shell',
#  'ship',
#  'shipped',
#  'shipping',
#  'shirley',
#  'shirley crenshaw',
#  'shop',
#  'shopping',
#  'short',
#  'short term',
#  'shortly',
#  'shouid',
#  'should',
#  'should be',
#  'should have',
#  'should not',
#  'show',
#  'showing',
#  'shows',
#  'shut',
#  'si',
#  'side',
#  'sie',
#  'sign',
#  'signed',
#  'significant',
#  'significantly',
#  'similar',
#  'simple',
#  'simply',
#  'since',
#  'since the',
#  'since we',
#  'sincerely',
#  'single',
#  'sir',
#  'sit',
#  'sitara',
#  'site',
#  'site and',
#  'sites',
#  'situation',
#  'six',
#  'size',
#  'skilling',
#  'skills',
#  'small',
#  'smaller',
#  'smith',
#  'smtp',
#  'so',
#  'so far',
#  'so much',
#  'so that',
#  'so we',
#  'so you',
#  'socal',
#  'social',
#  'soft',
#  'soft tabs',
#  'software',
#  'softwares',
#  'sold',
#  'solicitation',
#  'solution',
#  'solutions',
#  'some',
#  'some of',
#  'some time',
#  'someone',
#  'something',
#  'sometimes',
#  'son',
#  'soon',
#  'soon as',
#  'sorry',
#  'sort',
#  'sound',
#  'source',
#  'sources',
#  'south',
#  'south africa',
#  'southern',
#  'southwest',
#  'sp',
#  'space',
#  'spam',
#  'speak',
#  'speaker',
#  'special',
#  'specific',
#  'specifically',
#  'speculative',
#  'speed',
#  'spend',
#  'spending',
#  'spent',
#  'split',
#  'spoke',
#  'spoke with',
#  'spokesman',
#  'spokeswoman',
#  'sponsored',
#  'sports',
#  'spot',
#  'spread',
#  'spreadsheet',
#  'spring',
#  'squirrelmail',
#  'src',
#  'src http',
#  'st',
#  'staff',
#  'stage',
#  'stake',
#  'stake in',
#  'stand',
#  'standard',
#  'standard poor',
#  'standards',
#  'stanford',
#  'star',
#  'start',
#  'start date',
#  'started',
#  'starting',
#  'state',
#  'state of',
#  'stated',
#  'statement',
#  'statements',
#  'statements are',
#  'statements forward',
#  'statements in',
#  'statements indicating',
#  'statements of',
#  'statements that',
#  'statements within',
#  'states',
#  'states dollars',
#  'station',
#  'stationery',
#  'status',
#  'stay',
#  'stem',
#  'step',
#  'stephen',
#  'steps',
#  'steve',
#  'steven',
#  'still',
#  'stinson',
#  'stinson gibner',
#  'stock',
#  'stock exchange',
#  'stock is',
#  'stock price',
#  'stock the',
#  'stocks',
#  'stocks are',
#  'stocks featured',
#  'stocks securities',
#  'stop',
#  'stop future',
#  'storage',
#  'store',
#  'story',
#  'strategic',
#  'strategies',
#  'strategy',
#  'stream',
#  'street',
#  'street journal',
#  'strictly',
#  'strong',
#  'structure',
#  'structured',
#  'structuring',
#  'student',
#  'students',
#  'studio',
#  'studio mx',
#  'study',
#  'stuff',
#  'style',
#  'su',
#  'subject',
#  'subject enron',
#  'subject fw',
#  'subject get',
#  'subject hpl',
#  'subject line',
#  'subject new',
#  'subject re',
#  'subject start',
#  'subject the',
#  'subject to',
#  'subject you',
#  'subject your',
#  'submit',
#  'submit your',
#  'submitted',
#  'subscribers',
#  'subscribers to',
#  'subscription',
#  'subsidiaries',
#  'subsidiary',
#  'substantial',
#  'success',
#  'success of',
#  'successful',
#  'such',
#  'such as',
#  'suggest',
#  'suggested',
#  'suggestions',
#  'suite',
#  'sum',
#  'sum of',
#  'summary',
#  'summer',
#  'sun',
#  'sunday',
#  'super',
#  'supplies',
#  'supply',
#  'support',
#  'sure',
#  'sure that',
#  'surprise',
#  'survey',
#  'susan',
#  'symbol',
#  'system',
#  'systems',
#  'table',
#  'tablets',
#  'tabs',
#  'tag',
#  'take',
#  'take advantage',
#  'take look',
#  'take the',
#  'taken',
#  'takeover',
#  'takes',
#  'taking',
#  'talk',
#  'talk to',
#  'talked',
#  'talking',
#  'talks',
#  'tanya',
#  'tap',
#  'target',
#  'target price',
#  'targeted',
#  'task',
#  'tax',
#  'tax accounting',
#  'taylor',
#  'td',
#  'tdtd',
#  'team',
#  'teams',
#  'tech',
#  'technical',
#  'technoiogy',
#  'technologies',
#  'technology',
#  'ted',
#  'tel',
#  'telephone',
#  'tell',
#  'ten',
#  'tenaska',
#  'tenaska iv',
#  'term',
#  'termination',
#  'terms',
#  'terms of',
#  'test',
#  'testing',
#  'texas',
#  'text',
#  'th',
#  'th of',
#  'than',
#  'than the',
#  'thank',
#  'thank you',
#  'thanks',
#  'thanks for',
#  'thanks http',
#  'thanks in',
#  'that',
#  'that all',
#  'that are',
#  'that by',
#  'that can',
#  'that could',
#  'that enron',
#  'that has',
#  'that have',
#  'that he',
#  'that if',
#  'that involve',
#  'that is',
#  'that it',
#  'that its',
#  'that may',
#  'that the',
#  'that there',
#  'that they',
#  'that this',
#  'that was',
#  'that we',
#  'that were',
#  'that will',
#  'that would',
#  'that you',
#  'that your',
#  'the',
#  'the ability',
#  'the above',
#  'the address',
#  'the amount',
#  'the attached',
#  'the bank',
#  'the best',
#  'the big',
#  'the biggest',
#  'the board',
#  'the business',
#  'the california',
#  'the call',
#  'the case',
#  'the cash',
#  'the chairman',
#  'the commission',
#  'the companies',
#  'the company',
#  'the conference',
#  'the contents',
#  'the contract',
#  'the cost',
#  'the country',
#  'the credit',
#  'the current',
#  'the data',
#  'the date',
#  'the day',
#  'the deal',
#  'the details',
#  'the development',
#  'the end',
#  'the energy',
#  'the enron',
#  'the entire',
#  'the event',
#  'the fact',
#  'the federal',
#  'the final',
#  'the financial',
#  'the firm',
#  'the first',
#  'the following',
#  'the form',
#  'the forward',
#  'the full',
#  'the fund',
#  'the funds',
#  'the future',
#  'the gas',
#  'the global',
#  'the government',
#  'the group',
#  'the highest',
#  'the houston',
#  'the industry',
#  'the information',
#  'the internet',
#  'the investment',
#  'the iso',
#  'the issue',
#  'the largest',
#  'the last',
#  'the latest',
#  'the link',
#  'the list',
#  'the long',
#  'the lowest',
#  'the market',
#  'the material',
#  'the meaning',
#  'the meeting',
#  'the merger',
#  'the message',
#  'the money',
#  'the month',
#  'the most',
#  'the name',
#  'the nation',
#  'the necessary',
#  'the need',
#  'the net',
#  'the new',
#  'the news',
#  'the next',
#  'the number',
#  'the office',
#  'the one',
#  'the only',
#  'the opportunity',
#  'the order',
#  'the original',
#  'the other',
#  'the partnerships',
#  'the past',
#  'the people',
#  'the plan',
#  'the plant',
#  'the potential',
#  'the power',
#  'the price',
#  'the private',
#  'the problem',
#  'the process',
#  'the product',
#  'the program',
#  'the project',
#  'the property',
#  'the proposed',
#  'the pubiisher',
#  'the publisher',
#  'the purchase',
#  'the real',
#  'the receipt',
#  'the report',
#  'the request',
#  'the research',
#  'the rest',
#  'the result',
#  'the results',
#  'the right',
#  'the risk',
#  'the sale',
#  'the same',
#  'the sec',
#  'the second',
#  'the securities',
#  'the security',
#  'the senate',
#  'the sender',
#  'the site',
#  'the situation',
#  'the size',
#  'the state',
#  'the statements',
#  'the stock',
#  'the subject',
#  'the system',
#  'the th',
#  'the third',
#  'the time',
#  'the top',
#  'the total',
#  'the trading',
#  'the transaction',
#  'the two',
#  'the united',
#  'the university',
#  'the us',
#  'the use',
#  'the value',
#  'the wall',
#  'the way',
#  'the web',
#  'the week',
#  'the west',
#  'the whole',
#  'the world',
#  'the year',
#  'thecompany',
#  'their',
#  'their own',
#  'them',
#  'them to',
#  'themselves',
#  'then',
#  'then you',
#  'there',
#  'there are',
#  'there can',
#  'there is',
#  'there was',
#  'there will',
#  'therefore',
#  'therein',
#  'these',
#  'these are',
#  'these companies',
#  'these terms',
#  'they',
#  'they are',
#  'they can',
#  'they have',
#  'they re',
#  'they were',
#  'they will',
#  'they would',
#  'thing',
#  'things',
#  'think',
#  'think it',
#  'think that',
#  'think we',
#  'thinking',
#  'third',
#  'third party',
#  'third quarter',
#  'this',
#  'this action',
#  'this business',
#  'this company',
#  'this deal',
#  'this emai',
#  'this email',
#  'this information',
#  'this is',
#  'this issue',
#  'this letter',
#  'this link',
#  'this list',
#  'this mail',
#  'this message',
#  'this money',
#  'this month',
#  'this morning',
#  'this newsietter',
#  'this newsletter',
#  'this one',
#  'this operation',
#  'this point',
#  'this program',
#  'this project',
#  'this publication',
#  'this report',
#  'this stock',
#  'this time',
#  'this to',
#  'this transaction',
#  'this was',
#  'this week',
#  'this will',
#  'this year',
#  'thomas',
#  'thorough',
#  'those',
#  'those who',
#  'though',
#  'thought',
#  'thoughts',
#  'thousand',
#  'thousands',
#  'thousands of',
#  'three',
#  'through',
#  'through the',
#  'throughout',
#  'throughout the',
#  'thru',
#  'thu',
#  'thursday',
#  'thus',
#  'ticket',
#  'tickets',
#  'till',
#  'tim',
#  'time',
#  'time and',
#  'time for',
#  'time the',
#  'time this',
#  'time to',
#  'timely',
#  'times',
#  'timing',
#  'title',
#  'titles',
#  'tm',
#  'to',
#  'to 10',
#  'to achieve',
#  'to acquire',
#  'to act',
#  'to address',
#  'to all',
#  'to an',
#  'to announce',
#  'to any',
#  'to ask',
#  'to assist',
#  'to attend',
#  'to avoid',
#  'to be',
#  'to begin',
#  'to bring',
#  'to build',
#  'to buy',
#  'to call',
#  'to change',
#  'to check',
#  'to choose',
#  'to claim',
#  'to close',
#  'to come',
#  'to company',
#  'to complete',
#  'to confirm',
#  'to consider',
#  'to contact',
#  'to continue',
#  'to cover',
#  'to create',
#  'to date',
#  'to deliver',
#  'to determine',
#  'to develop',
#  'to differ',
#  'to discuss',
#  'to do',
#  'to enable',
#  'to enron',
#  'to ensure',
#  'to file',
#  'to find',
#  'to get',
#  'to give',
#  'to go',
#  'to have',
#  'to hear',
#  'to hearing',
#  'to help',
#  'to her',
#  'to him',
#  'to his',
#  'to houston',
#  'to identify',
#  'to include',
#  'to increase',
#  'to inform',
#  'to invest',
#  'to investing',
#  'to its',
#  'to join',
#  'to keep',
#  'to know',
#  'to learn',
#  'to let',
#  'to look',
#  'to lose',
#  'to make',
#  'to manage',
#  'to market',
#  'to me',
#  'to meet',
#  'to move',
#  'to my',
#  'to offer',
#  'to one',
#  'to order',
#  'to our',
#  'to participate',
#  'to pay',
#  'to predictions',
#  'to provide',
#  'to purchase',
#  'to put',
#  'to raise',
#  'to reach',
#  'to read',
#  'to receive',
#  'to review',
#  'to run',
#  'to save',
#  'to say',
#  'to see',
#  'to seek',
#  'to sell',
#  'to send',
#  'to serve',
#  'to set',
#  'to start',
#  'to stop',
#  'to support',
#  'to take',
#  'to talk',
#  'to that',
#  'to the',
#  'to their',
#  'to them',
#  'to this',
#  'to trade',
#  'to try',
#  'to unsubscribe',
#  'to update',
#  'to us',
#  'to use',
#  'to wait',
#  'to work',
#  'to you',
#  'to your',
#  'today',
#  'today and',
#  'together',
#  'told',
#  'tom',
#  'tomorrow',
#  'tony',
#  'too',
#  'took',
#  'tool',
#  'tools',
#  'top',
#  'total',
#  'tothe',
#  'touch',
#  'tour',
#  'toward',
#  'towards',
#  'town',
#  'track',
#  'trade',
#  'trade in',
#  'traded',
#  'trader',
#  'traders',
#  'trades',
#  'trading',
#  'trading and',
#  'trading business',
#  'training',
#  'transaction',
#  'transaction is',
#  'transactions',
#  'transfer',
#  'transferred',
#  'transition',
#  'transmission',
#  'transport',
#  'transportation',
#  'transwestern',
#  'travel',
#  'treasury',
#  'treated',
#  'treatment',
#  'trial',
#  'tried',
#  'tried to',
#  'trip',
#  'trouble',
#  'true',
#  'trust',
#  'try',
#  'try to',
#  'trying',
#  'trying to',
#  'tu',
#  'tue',
#  'tue 19',
#  'tuesday',
#  'turbine',
#  'turn',
#  'turned',
#  'tv',
#  'tw',
#  'twenty',
#  'two',
#  'two weeks',
#  'two years',
#  'tx',
#  'txt',
#  'txu',
#  'type',
#  'type of',
#  'types',
#  'ubs',
#  'uk',
#  'un',
#  'unable',
#  'unable to',
#  'uncertainties',
#  'uncertainties which',
#  'unclaimed',
#  'under',
#  'under the',
#  'understand',
#  'understanding',
#  'understands',
#  'understood',
#  'understood as',
#  'unfortunately',
#  'unify',
#  'union',
#  'unique',
#  'unit',
#  'united',
#  'united states',
#  'units',
#  'university',
#  'university of',
#  'unknown',
#  'unknown database',
#  'unless',
#  'unlimited',
#  'unsubscribe',
#  'unsubscribe from',
#  'until',
#  'until the',
#  'up',
#  'up and',
#  'up for',
#  'up in',
#  'up of',
#  'up on',
#  'up the',
#  'up to',
#  'up with',
#  'update',
#  'updated',
#  'updates',
#  'upon',
#  'ur',
#  'urgent',
#  'url',
#  'us',
#  'us and',
#  'us at',
#  'us in',
#  'us know',
#  'us to',
#  'usa',
#  'usage',
#  'usb',
#  'usd',
#  'use',
#  'use of',
#  'use the',
#  'used',
#  'used as',
#  'used to',
#  'useful',
#  'user',
#  'users',
#  'uses',
#  'using',
#  'using the',
#  'usually',
#  'ut',
#  'utf',
#  'utilities',
#  'utility',
#  'vacation',
#  'valid',
#  'valium',
#  'valuable',
#  'valuation',
#  'value',
#  'value of',
#  'valued',
#  'values',
#  'van',
#  'vance',
#  'var',
#  'variances',
#  'variances detected',
#  'variety',
#  'variety of',
#  'various',
#  'vasant',
#  've',
#  've been',
#  'vehicles',
#  'venture',
#  'verify',
#  'version',
#  'version of',
#  'versions',
#  'very',
#  'very much',
#  'via',
#  'viagra',
#  'viagra at',
#  'vice',
#  'vice president',
#  'video',
#  'view',
#  'vince',
#  'vince forwarded',
#  'vince kaminski',
#  'visa',
#  'visit',
#  'visit our',
#  'visit to',
#  'visual',
#  'vkamins',
#  'vnbl',
#  'voice',
#  'voip',
#  'vol',
#  'volatility',
#  'volume',
#  'volumes',
#  'vote',
#  'vp',
#  'vs',
#  'wa',
#  'wait',
#  'waiting',
#  'walk',
#  'wall',
#  'wall street',
#  'want',
#  'want to',
#  'want you',
#  'wanted',
#  'wanted to',
#  'wants',
#  'wants to',
#  'war',
#  'was',
#  'was in',
#  'was not',
#  'was sent',
#  'was the',
#  'washington',
#  'wasn',
#  'waste',
#  'watch',
#  'watch this',
#  'water',
#  'watson',
#  'way',
#  'way to',
#  'ways',
#  'we',
#  'we also',
#  'we are',
#  'we believe',
#  'we can',
#  'we could',
#  'we do',
#  'we don',
#  'we had',
#  'we have',
#  'we hope',
#  'we know',
#  'we ll',
#  'we look',
#  'we may',
#  'we need',
#  'we offer',
#  'we re',
#  'we should',
#  'we ve',
#  'we want',
#  'we were',
#  'we will',
#  'we would',
#  'weather',
#  'web',
#  'web site',
#  'web sites',
#  'website',
#  'website and',
#  'websites',
#  'wed',
#  'wednesday',
#  'week',
#  'week and',
#  'week of',
#  'weekend',
#  'weekly',
#  'weeks',
#  'weight',
#  'weil',
#  'wel',
#  'welcome',
#  'welcome to',
#  'well',
#  'well as',
#  'wellhead',
#  'wells',
#  'went',
#  'were',
#  'were selected',
#  'wes',
#  'west',
#  'westdesk',
#  'westdesk california',
#  'western',
#  'whalley',
#  'wharton',
#  'what',
#  'what is',
#  'what it',
#  'what the',
#  'what they',
#  'what we',
#  'what you',
#  'whatever',
#  'when',
#  'when it',
#  'when the',
#  'when they',
#  'when we',
#  'when you',
#  'where',
#  'where the',
#  'whether',
#  'which',
#  'which are',
#  'which could',
#  'which has',
#  'which have',
#  'which is',
#  'which the',
#  'which was',
#  'which we',
#  'which will',
#  'while',
#  'while the',
#  'white',
#  'who',
#  'who are',
#  'who has',
#  'who have',
#  'who is',
#  'who was',
#  'who will',
#  'whole',
#  'wholesale',
#  'whom',
#  'whose',
#  'why',
#  'wi',
#  'wide',
#  'width',
#  'wife',
#  'wiil',
#  'wil',
#  'will',
#  'will also',
#  'will be',
#  'will continue',
#  'will get',
#  'will give',
#  'will have',
#  'will help',
#  'will make',
#  'will need',
#  'will not',
#  'will provide',
#  'will receive',
#  'will take',
#  'will work',
#  'william',
#  'williams',
#  'willing',
#  'willing to',
#  'win',
#  'wind',
#  'window',
#  'windows',
#  'windows xp',
#  'winner',
#  'winners',
#  'winning',
#  'winter',
#  'wire',
#  'wireless',
#  'wish',
#  'wish to',
#  'with',
#  'with all',
#  'with an',
#  'with any',
#  'with enron',
#  'with it',
#  'with its',
#  'with me',
#  'with my',
#  'with no',
#  'with our',
#  'with remove',
#  'with respect',
#  'with the',
#  'with their',
#  'with them',
#  'with this',
#  'with us',
#  'with you',
#  'with your',
#  'within',
#  'within the',
#  'within this',
#  'without',
#  'without notice',
#  'woman',
#  'women',
#  'won',
#  'wood',
#  'word',
#  'words',
#  'words such',
#  'work',
#  'work for',
#  'work on',
#  'work with',
#  'worked',
#  'working',
#  'working on',
#  'working with',
#  'works',
#  'world',
#  'world wide',
#  'worldwide',
#  'worth',
#  'would',
#  'would be',
#  'would have',
#  'would like',
#  'would not',
#  'would you',
#  'wouldn',
#  'write',
#  'writing',
#  'written',
#  'wrong',
#  'wrote',
#  'www',
#  'www computron',
#  'wyoming',
#  'wysak',
#  'wysk',
#  'xanax',
#  'xls',
#  'xp',
#  'xp pro',
#  'xp professional',
#  'yahoo',
#  'yahoo com',
#  'yap',
#  'year',
#  'year and',
#  'years',
#  'years of',
#  'yes',
#  'yesterday',
#  'yet',
#  'yield',
#  'yo',
#  'york',
#  'york stock',
#  'york times',
#  'you',
#  'you all',
#  'you an',
#  'you and',
#  'you are',
#  'you as',
#  'you at',
#  'you by',
#  'you can',
#  'you could',
#  'you do',
#  'you don',
#  'you feel',
#  'you for',
#  'you get',
#  'you have',
#  'you in',
#  'you know',
#  'you like',
#  'you ll',
#  'you may',
#  'you might',
#  'you must',
#  'you need',
#  'you of',
#  'you on',
#  'you or',
#  'you please',
#  'you re',
#  'you save',
#  'you should',
#  'you that',
#  'you the',
#  'you think',
#  'you this',
#  'you to',
#  'you ve',
#  'you want',
#  'you we',
#  'you were',
#  'you will',
#  'you wish',
#  'you with',
#  'you would',
#  'young',
#  'your',
#  'your account',
#  'your assistance',
#  'your browser',
#  'your business',
#  'your claim',
#  'your claims',
#  'your company',
#  'your country',
#  'your email',
#  'your free',
#  'your group',
#  'your help',
#  'your information',
#  'your life',
#  'your mail',
#  'your message',
#  'your money',
#  'your name',
#  'your order',
#  'your own',
#  'your prize',
#  'your reference',
#  'your site',
#  'your time',
#  'your website',
#  'yours',
#  'yourself',
#  'zero',
#  'zimin',
#  'zone']

# %%
#Baseline classifier
from sklearn.dummy import DummyClassifier
from sklearn.metrics import f1_score

base = DummyClassifier(strategy='most_frequent')
base.fit(X_train_tfidf, y_train)
predictions = base.predict(X_train_tfidf)
score = f1_score(y_train, predictions)
print("train f1-score:",score)

predictions_test = base.predict(X_test_tfidf)
score = f1_score(y_test, predictions_test)
print("test f1-score:",score)
print()
print("test data confusion matrix")
y_true = pd.Series(y_test, name='True')
y_pred = pd.Series(predictions_test, name='Predicted')
pd.crosstab(y_true, y_pred)
# Out:
# train f1-score: 0.674287319196742
# test f1-score: 0.6762203900013087
#
# test data confusion matrix
# Predicted     1
# True
# 0          4948
# 1          5167

# %%
#Naive-Bayes classifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import f1_score

clf = MultinomialNB()
clf.fit(X_train_tfidf, y_train)
predictions = clf.predict(X_train_tfidf)
score = f1_score(y_train,predictions)
print("train f1-score:",score)

predictions_test = clf.predict(X_test_tfidf)
score = f1_score(y_test, predictions_test)
print("test f1-score:",score)
print()
print("test data confusion matrix")
y_true = pd.Series(y_test, name='True')
y_pred = pd.Series(predictions_test, name='Predicted')
pd.crosstab(y_true, y_pred)
# Out:
# train f1-score: 0.9746824935668632
# test f1-score: 0.9791344667697063
#
# test data confusion matrix
# Predicted     0     1
# True
# 0          4831   117
# 1            99  5068

# %%
#Logistic Regression
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score

clf = LogisticRegression(solver="liblinear")
clf.fit(X_train_tfidf, y_train)
predictions = clf.predict(X_train_tfidf)
score = f1_score(y_train,predictions)
print("train f1-score:",score)

predictions_test = clf.predict(X_test_tfidf)
score = f1_score(y_test, predictions_test)
print("test f1-score:",score)
print()
print("test data confusion matrix")
y_true = pd.Series(y_test, name='True')
y_pred = pd.Series(predictions_test, name='Predicted')
pd.crosstab(y_true, y_pred)
# Out:
# train f1-score: 0.987997682311067
# test f1-score: 0.986530690783144
#
# test data confusion matrix
# Predicted     0     1
# True
# 0          4848   100
# 1            40  5127

# %%
# Reduce dimensionality using svd
from sklearn.decomposition import TruncatedSVD

svd = TruncatedSVD(n_components=100, random_state=4321)
X_train_svd = svd.fit_transform(X_train_tfidf)
X_test_svd = svd.transform(X_test_tfidf)

# %%
from sklearn import svm
from sklearn.metrics import f1_score


clf = svm.SVC(kernel='linear')
clf.fit(X_train_tfidf, y_train)
predictions = clf.predict(X_train_tfidf)
score = f1_score(y_train,predictions)
print("train f1-score:",score)

predictions_test = clf.predict(X_test_tfidf)
score = f1_score(y_test, predictions_test)
print("test f1-score:",score)
print()
print("test data confusion matrix")
y_true = pd.Series(y_test, name='True')
y_pred = pd.Series(predictions_test, name='Predicted')
pd.crosstab(y_true, y_pred)
# Out:
# train f1-score: 0.992743707758013
# test f1-score: 0.9876590821442345
#
# test data confusion matrix
# Predicted     0     1
# True
# 0          4865    83
# 1            45  5122

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import f1_score

clf = KNeighborsClassifier(n_neighbors=5)
clf.fit(X_train_svd, y_train)
predictions = clf.predict(X_train_svd)
score = f1_score(y_train,predictions)
print("train f1-score:",score)

predictions_test = clf.predict(X_test_svd)
score = f1_score(y_test, predictions_test)
print("test f1-score:",score)
print()
print("test data confusion matrix")
y_true = pd.Series(y_test, name='True')
y_pred = pd.Series(predictions_test, name='Predicted')
pd.crosstab(y_true, y_pred)
# Out:
# train f1-score: 0.9817970726043869
# test f1-score: 0.9742799344957134
#
# test data confusion matrix
# Predicted     0     1
# True
# 0          4791   157
# 1           110  5057

# %%
#MLP Classifier with 2 hidden layers
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import f1_score

clf = MLPClassifier(solver='adam',hidden_layer_sizes=(200,200),early_stopping=True,random_state=123456)
clf.fit(X_train_tfidf, y_train)

predictions = clf.predict(X_train_tfidf)
score = f1_score(y_train,predictions)
print("train f1-score:",score)

predictions_test = clf.predict(X_test_tfidf)
score = f1_score(y_test, predictions_test)
print("test f1-score:",score)
print()
print("test data confusion matrix")
y_true = pd.Series(y_test, name='True')
y_pred = pd.Series(predictions_test, name='Predicted')
pd.crosstab(y_true, y_pred)
# Out:
# train f1-score: 0.9962979909321575
# test f1-score: 0.9882899448369302
#
# test data confusion matrix
# Predicted     0     1
# True
# 0          4888    60
# 1            61  5106

# %%
#Hyper-parameter tuning via grid search
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score


hyper_parameter_grid = [{'solver': ['newton-cg','liblinear'],'C': [1, 10, 100, 1000]}]              
clf = GridSearchCV(LogisticRegression(), hyper_parameter_grid, cv=5,scoring='f1',n_jobs=1)
clf.fit(X_train_tfidf, y_train)

print("Best parameters set found on development set:")
print()
print(clf.best_params_)
print()
print("Grid scores on development set:")
print()
means = clf.cv_results_['mean_test_score']
stds = clf.cv_results_['std_test_score']
for mean, std, params in zip(means, stds, clf.cv_results_['params']):
    print("%0.3f (+%0.03f) for %r"% (mean, std * 2, params))
    print()

print()
print("Test data classification report:")
print()
y_true, y_pred = y_test, clf.predict(X_test_tfidf)
print(classification_report(y_true, y_pred))
score = f1_score(y_true, y_pred)
print("test f1-score:",score)
# Out:
# Best parameters set found on development set:
#
# {'C': 10, 'solver': 'newton-cg'}
#
# Grid scores on development set:
#
# 0.983 (+0.003) for {'C': 1, 'solver': 'newton-cg'}
#
# 0.983 (+0.003) for {'C': 1, 'solver': 'liblinear'}
#
# 0.985 (+0.003) for {'C': 10, 'solver': 'newton-cg'}
#
# 0.985 (+0.003) for {'C': 10, 'solver': 'liblinear'}
#
# 0.984 (+0.002) for {'C': 100, 'solver': 'newton-cg'}
#
# 0.984 (+0.002) for {'C': 100, 'solver': 'liblinear'}
#
# 0.983 (+0.002) for {'C': 1000, 'solver': 'newton-cg'}
#
# 0.983 (+0.002) for {'C': 1000, 'solver': 'liblinear'}
#
#
# Test data classification report:
#
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99      4948
#            1       0.99      0.99      0.99      5167
#
#    micro avg       0.99      0.99      0.99     10115
#    macro avg       0.99      0.99      0.99     10115
# weighted avg       0.99      0.99      0.99     10115
#
# test f1-score: 0.9874444659068958

# %%
#Learning curves with cross-validtion
import numpy as np
import matplotlib.pyplot as plt
from sklearn.naive_bayes import MultinomialNB
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import learning_curve
from sklearn.model_selection import ShuffleSplit

def plot_learning_curve(estimator, title, X, y, ylim=None, cv=None,
                        n_jobs=1, train_sizes=np.linspace(.1, 1.0, 5)):
   
    plt.figure()
    plt.title(title)
    if ylim is not None:
        plt.ylim(*ylim)
    plt.xlabel("Training examples")
    plt.ylabel("F1-score")
    train_sizes, train_scores, test_scores = learning_curve(
        estimator, X, y, cv=cv, n_jobs=n_jobs,scoring='f1', train_sizes=train_sizes)
    train_scores_mean = np.mean(train_scores, axis=1)
    train_scores_std = np.std(train_scores, axis=1)
    test_scores_mean = np.mean(test_scores, axis=1)
    test_scores_std = np.std(test_scores, axis=1)
    plt.grid()

    plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                     train_scores_mean + train_scores_std, alpha=0.1,
                     color="b")
    plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                     test_scores_mean + test_scores_std, alpha=0.1, color="orange")
    plt.plot(train_sizes, train_scores_mean, 'o-', color="b",
             label="Training score")
    plt.plot(train_sizes, test_scores_mean, 'o-', color="orange",
             label="Cross-validation score")

    plt.legend(loc="lower right")
    return plt


X, y = X_train_tfidf,y_train

title = "Learning Curves (Naive Bayes)"
cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)
estimator = MultinomialNB()
plot_learning_curve(estimator, title, X, y, ylim=(0.7, 1.01), cv=cv, n_jobs=2)
plt.show()

title = "Learning Curves (Logistic Regression)"
cv = ShuffleSplit(n_splits=5, test_size=0.2, random_state=0)
estimator = LogisticRegression()
plot_learning_curve(estimator, title, X, y, (0.7, 1.01), cv=cv, n_jobs=2)
plt.show()

# %%
#Precision-Recall curves
import numpy as np
from sklearn.metrics import precision_recall_curve
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import auc
import matplotlib.pyplot as plt
from sklearn.naive_bayes import MultinomialNB


#disable warnings for large float numbers of estimated probabilities
np.seterr(all='ignore')
estimators = {'Logistic Regression':LogisticRegression(solver='liblinear'), 'Naive Bayes ':MultinomialNB()}

for (name,estimator) in estimators.items():
    
    model =estimator
    model.fit(X_train_tfidf,y_train)
    pred = model.predict_proba(X_test_tfidf)
    precision, recall, thresholds = precision_recall_curve(y_test, pred[:,1])
    area = auc(recall, precision)

    plt.plot(recall, precision, label='Precision-Recall curve')
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.ylim([0.0, 1.05])
    plt.xlim([0.0, 1.0])
    plt.title('Precision-Recall %s: AUC=%0.2f' % (name,area))
    plt.legend(loc="lower left")
    plt.show()
